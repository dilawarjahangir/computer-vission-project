# %%
import os
import cv2
import numpy as np
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.preprocessing import LabelEncoder
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
import joblib

# %%
import os
import cv2
import numpy as np
import joblib
from skimage.feature import hog
from sklearn.preprocessing import LabelEncoder
from sklearn.svm import SVC
from sklearn.decomposition import PCA

def extract_hog_features(image):
    hog_features, hog_image = hog(image, 
                                  orientations=9, 
                                  pixels_per_cell=(8, 8), 
                                  cells_per_block=(2, 2), 
                                  block_norm='L2-Hys', 
                                  visualize=True, 
                                  feature_vector=True)
    return hog_features

def load_and_preprocess_images(dataset_path, categories, image_size, apply_pca=False, n_components=50):
    data = []
    labels = []
    
    for category in categories:
        folder_path = os.path.join(dataset_path, category)
        
        for filename in os.listdir(folder_path):
            image_path = os.path.join(folder_path, filename)
            image = cv2.imread(image_path)
            if image is None:
                continue
            
            print(f"Processing: {filename}")
            resized_image = cv2.resize(image, image_size)
            gray_image = cv2.cvtColor(resized_image, cv2.COLOR_BGR2GRAY)
            
            hog_features = extract_hog_features(gray_image)
            
            data.append(hog_features)
            labels.append(category)
    
    data = np.array(data)
    labels = np.array(labels)
    
    label_encoder = LabelEncoder()
    encoded_labels = label_encoder.fit_transform(labels)
    
    if apply_pca:
        pca = PCA(n_components=n_components)
        data = pca.fit_transform(data)
        return data, encoded_labels, label_encoder, pca
    else:
        return data, encoded_labels, label_encoder, None

IMAGE_SIZE = (128, 128)
DATASET_PATH = '../dataset/images'
CATEGORIES = ['cars', 'motorcycles', 'non_vehicles']

data, labels, label_encoder, pca = load_and_preprocess_images(dataset_path=DATASET_PATH, 
                                                              categories=CATEGORIES, 
                                                              image_size=IMAGE_SIZE, 
                                                              apply_pca=True,  # Set to False if you don't want PCA
                                                              n_components=50)  # Adjust the number of components as needed

model = SVC(kernel='linear')
model.fit(data, labels)

joblib.dump(model, 'vehicle_detection_model.pkl')
if pca is not None:
    joblib.dump(pca, 'pca_model.pkl')
joblib.dump(label_encoder, 'label_encoder.pkl')

print("Model, PCA, and Label Encoder saved successfully!")
# Out:
# Processing: 1.jpg
# Processing: 10.jpg
# Processing: 100.jpg
# Processing: 1000.jpg
# Processing: 1001.jpg
# Processing: 1002.jpg
# Processing: 1003.jpg
# Processing: 1004.jpg
# Processing: 1005.jpg
# Processing: 1006.jpg
# Processing: 1007.jpg
# Processing: 1008.jpg
# Processing: 1009.jpg
# Processing: 101.jpg
# Processing: 1010.jpg
# Processing: 1011.jpg
# Processing: 1012.jpg
# Processing: 1013.jpg
# Processing: 1014.jpg
# Processing: 1015.jpg
# Processing: 1016.jpg
# Processing: 1017.jpg
# Processing: 1018.jpg
# Processing: 1019.jpg
# Processing: 102.jpg
# Processing: 1020.jpg
# Processing: 1021.jpg
# Processing: 1022.jpg
# Processing: 1023.jpg
# Processing: 1024.jpg
# Processing: 1025.jpg
# Processing: 1026.jpg
# Processing: 1027.jpg
# Processing: 1028.jpg
# Processing: 1029.jpg
# Processing: 103.jpg
# Processing: 1030.jpg
# Processing: 1031.jpg
# Processing: 1032.jpg
# Processing: 1033.jpg
# Processing: 1034.jpg
# Processing: 1035.jpg
# Processing: 1036.jpg
# Processing: 1037.jpg
# Processing: 1038.jpg
# Processing: 1039.jpg
# Processing: 104.jpg
# Processing: 1040.jpg
# Processing: 1041.jpg
# Processing: 1042.jpg
# Processing: 1043.jpg
# Processing: 1044.jpg
# Processing: 1045.jpg
# Processing: 1046.jpg
# Processing: 1047.jpg
# Processing: 1048.jpg
# Processing: 1049.jpg
# Processing: 105.jpg
# Processing: 1050.jpg
# Processing: 1051.jpg
# Processing: 1052.jpg
# Processing: 1053.jpg
# Processing: 1054.jpg
# Processing: 1055.jpg
# Processing: 1056.jpg
# Processing: 1057.jpg
# Processing: 1058.jpg
# Processing: 1059.jpg
# Processing: 106.jpg
# Processing: 1060.jpg
# Processing: 1061.jpg
# Processing: 1062.jpg
# Processing: 1063.jpg
# Processing: 1064.jpg
# Processing: 1065.jpg
# Processing: 1066.jpg
# Processing: 1067.jpg
# Processing: 1068.jpg
# Processing: 1069.jpg
# Processing: 107.jpg
# Processing: 1070.jpg
# Processing: 1071.jpg
# Processing: 1072.jpg
# Processing: 1073.jpg
# Processing: 1074.jpg
# Processing: 1075.jpg
# Processing: 1076.jpg
# Processing: 1077.jpg
# Processing: 1078.jpg
# Processing: 1079.jpg
# Processing: 108.jpg
# Processing: 1080.jpg
# Processing: 1081.jpg
# Processing: 1082.jpg
# Processing: 1083.jpg
# Processing: 1084.jpg
# Processing: 1085.jpg
# Processing: 1086.jpg
# Processing: 1087.jpg
# Processing: 1088.jpg
# Processing: 1089.jpg
# Processing: 109.jpg
# Processing: 1090.jpg
# Processing: 1091.jpg
# Processing: 1092.jpg
# Processing: 1093.jpg
# Processing: 1094.jpg
# Processing: 1095.jpg
# Processing: 1096.jpg
# Processing: 1097.jpg
# Processing: 1098.jpg
# Processing: 1099.jpg
# Processing: 11.jpg
# Processing: 110.jpg
# Processing: 1100.jpg
# Processing: 1101.jpg
# Processing: 1102.jpg
# Processing: 1103.jpg
# Processing: 1104.jpg
# Processing: 1105.jpg
# Processing: 1106.jpg
# Processing: 1107.jpg
# Processing: 1108.jpg
# Processing: 1109.jpg
# Processing: 111.jpg
# Processing: 1110.jpg
# Processing: 1111.jpg
# Processing: 1112.jpg
# Processing: 1113.jpg
# Processing: 1114.jpg
# Processing: 1115.jpg
# Processing: 1116.jpg
# Processing: 1117.jpg
# Processing: 1118.jpg
# Processing: 1119.jpg
# Processing: 112.jpg
# Processing: 1120.jpg
# Processing: 1121.jpg
# Processing: 1122.jpg
# Processing: 1123.jpg
# Processing: 1124.jpg
# Processing: 1125.jpg
# Processing: 1126.jpg
# Processing: 1127.jpg
# Processing: 1128.jpg
# Processing: 1129.jpg
# Processing: 113.jpg
# Processing: 1130.jpg
# Processing: 1131.jpg
# Processing: 1132.jpg
# Processing: 1133.jpg
# Processing: 1134.jpg
# Processing: 1135.jpg
# Processing: 1136.jpg
# Processing: 1137.jpg
# Processing: 1138.jpg
# Processing: 1139.jpg
# Processing: 114.jpg
# Processing: 1140.jpg
# Processing: 1141.jpg
# Processing: 1142.jpg
# Processing: 1143.jpg
# Processing: 1144.jpg
# Processing: 1145.jpg
# Processing: 1146.jpg
# Processing: 1147.jpg
# Processing: 1148.jpg
# Processing: 1149.jpg
# Processing: 115.jpg
# Processing: 1150.jpg
# Processing: 1151.jpg
# Processing: 1152.jpg
# Processing: 1153.jpg
# Processing: 1154.jpg
# Processing: 1155.jpg
# Processing: 1156.jpg
# Processing: 1157.jpg
# Processing: 1158.jpg
# Processing: 1159.jpg
# Processing: 116.jpg
# Processing: 1160.jpg
# Processing: 1161.jpg
# Processing: 1162.jpg
# Processing: 1163.jpg
# Processing: 1164.jpg
# Processing: 1165.jpg
# Processing: 1166.jpg
# Processing: 1167.jpg
# Processing: 1168.jpg
# Processing: 1169.jpg
# Processing: 117.jpg
# Processing: 1170.jpg
# Processing: 1171.jpg
# Processing: 1172.jpg
# Processing: 1173.jpg
# Processing: 1174.jpg
# Processing: 1175.jpg
# Processing: 1176.jpg
# Processing: 1177.jpg
# Processing: 1178.jpg
# Processing: 1179.jpg
# Processing: 118.jpg
# Processing: 1180.jpg
# Processing: 1181.jpg
# Processing: 1182.jpg
# Processing: 1183.jpg
# Processing: 1184.jpg
# Processing: 1185.jpg
# Processing: 1186.jpg
# Processing: 1187.jpg
# Processing: 1188.jpg
# Processing: 1189.jpg
# Processing: 119.jpg
# Processing: 1190.jpg
# Processing: 1191.jpg
# Processing: 1192.jpg
# Processing: 1193.jpg
# Processing: 1194.jpg
# Processing: 1195.jpg
# Processing: 1196.jpg
# Processing: 1197.jpg
# Processing: 1198.jpg
# Processing: 1199.jpg
# Processing: 12.jpg
# Processing: 120.jpg
# Processing: 1200.jpg
# Processing: 1201.jpg
# Processing: 1202.jpg
# Processing: 1203.jpg
# Processing: 1204.jpg
# Processing: 1205.jpg
# Processing: 1206.jpg
# Processing: 1207.jpg
# Processing: 1208.jpg
# Processing: 1209.jpg
# Processing: 121.jpg
# Processing: 1210.jpg
# Processing: 1211.jpg
# Processing: 1212.jpg
# Processing: 1213.jpg
# Processing: 1214.jpg
# Processing: 1215.jpg
# Processing: 1216.jpg
# Processing: 1217.jpg
# Processing: 1218.jpg
# Processing: 1219.jpg
# Processing: 122.jpg
# Processing: 1220.jpg
# Processing: 1221.jpg
# Processing: 1222.jpg
# Processing: 1223.jpg
# Processing: 1224.jpg
# Processing: 1225.jpg
# Processing: 1226.jpg
# Processing: 1227.jpg
# Processing: 1228.jpg
# Processing: 1229.jpg
# Processing: 123.jpg
# Processing: 1230.jpg
# Processing: 1231.jpg
# Processing: 1232.jpg
# Processing: 1233.jpg
# Processing: 1234.jpg
# Processing: 1235.jpg
# Processing: 1236.jpg
# Processing: 1237.jpg
# Processing: 1238.jpg
# Processing: 1239.jpg
# Processing: 124.jpg
# Processing: 1240.jpg
# Processing: 1241.jpg
# Processing: 1242.jpg
# Processing: 1243.jpg
# Processing: 1244.jpg
# Processing: 1245.jpg
# Processing: 1246.jpg
# Processing: 1247.jpg
# Processing: 1248.jpg
# Processing: 1249.jpg
# Processing: 125.jpg
# Processing: 1250.jpg
# Processing: 1251.jpg
# Processing: 1252.jpg
# Processing: 1253.jpg
# Processing: 1254.jpg
# Processing: 1255.jpg
# Processing: 1256.jpg
# Processing: 1257.jpg
# Processing: 1258.jpg
# Processing: 1259.jpg
# Processing: 126.jpg
# Processing: 1260.jpg
# Processing: 1261.jpg
# Processing: 1262.jpg
# Processing: 1263.jpg
# Processing: 1264.jpg
# Processing: 1265.jpg
# Processing: 1266.jpg
# Processing: 1267.jpg
# Processing: 1268.jpg
# Processing: 1269.jpg
# Processing: 127.jpg
# Processing: 1270.jpg
# Processing: 1271.jpg
# Processing: 1272.jpg
# Processing: 1273.jpg
# Processing: 1274.jpg
# Processing: 1275.jpg
# Processing: 1276.jpg
# Processing: 1277.jpg
# Processing: 1278.jpg
# Processing: 1279.jpg
# Processing: 128.jpg
# Processing: 1280.jpg
# Processing: 1281.jpg
# Processing: 1282.jpg
# Processing: 1283.jpg
# Processing: 1284.jpg
# Processing: 1285.jpg
# Processing: 1286.jpg
# Processing: 1287.jpg
# Processing: 1288.jpg
# Processing: 1289.jpg
# Processing: 129.jpg
# Processing: 1290.jpg
# Processing: 1291.jpg
# Processing: 1292.jpg
# Processing: 1293.jpg
# Processing: 1294.jpg
# Processing: 1295.jpg
# Processing: 1296.jpg
# Processing: 1297.jpg
# Processing: 1298.jpg
# Processing: 1299.jpg
# Processing: 13.jpg
# Processing: 130.jpg
# Processing: 1300.jpg
# Processing: 1301.jpg
# Processing: 1302.jpg
# Processing: 1303.jpg
# Processing: 1304.jpg
# Processing: 1305.jpg
# Processing: 1306.jpg
# Processing: 1307.jpg
# Processing: 1308.jpg
# Processing: 1309.jpg
# Processing: 131.jpg
# Processing: 1310.jpg
# Processing: 1311.jpg
# Processing: 1312.jpg
# Processing: 1313.jpg
# Processing: 1314.jpg
# Processing: 1315.jpg
# Processing: 1316.jpg
# Processing: 1317.jpg
# Processing: 1318.jpg
# Processing: 1319.jpg
# Processing: 132.jpg
# Processing: 1320.jpg
# Processing: 1321.jpg
# Processing: 1322.jpg
# Processing: 1323.jpg
# Processing: 1324.jpg
# Processing: 1325.jpg
# Processing: 1326.jpg
# Processing: 1327.jpg
# Processing: 1328.jpg
# Processing: 1329.jpg
# Processing: 133.jpg
# Processing: 1330.jpg
# Processing: 1331.jpg
# Processing: 1332.jpg
# Processing: 1333.jpg
# Processing: 1334.jpg
# Processing: 1335.jpg
# Processing: 1336.jpg
# Processing: 1337.jpg
# Processing: 1338.jpg
# Processing: 1339.jpg
# Processing: 134.jpg
# Processing: 1340.jpg
# Processing: 1341.jpg
# Processing: 1342.jpg
# Processing: 1343.jpg
# Processing: 1344.jpg
# Processing: 1345.jpg
# Processing: 1346.jpg
# Processing: 1347.jpg
# Processing: 1348.jpg
# Processing: 1349.jpg
# Processing: 135.jpg
# Processing: 1350.jpg
# Processing: 1351.jpg
# Processing: 1352.jpg
# Processing: 1353.jpg
# Processing: 1354.jpg
# Processing: 1355.jpg
# Processing: 1356.jpg
# Processing: 1357.jpg
# Processing: 1358.jpg
# Processing: 1359.jpg
# Processing: 136.jpg
# Processing: 1360.jpg
# Processing: 1361.jpg
# Processing: 1362.jpg
# Processing: 1363.jpg
# Processing: 1364.jpg
# Processing: 1365.jpg
# Processing: 1366.jpg
# Processing: 1367.jpg
# Processing: 1368.jpg
# Processing: 1369.jpg
# Processing: 137.jpg
# Processing: 1370.jpg
# Processing: 1371.jpg
# Processing: 1372.jpg
# Processing: 1373.jpg
# Processing: 1374.jpg
# Processing: 1375.jpg
# Processing: 1376.jpg
# Processing: 1377.jpg
# Processing: 1378.jpg
# Processing: 1379.jpg
# Processing: 138.jpg
# Processing: 1380.jpg
# Processing: 1381.jpg
# Processing: 1382.jpg
# Processing: 1383.jpg
# Processing: 1384.jpg
# Processing: 1385.jpg
# Processing: 1386.jpg
# Processing: 1387.jpg
# Processing: 1388.jpg
# Processing: 1389.jpg
# Processing: 139.jpg
# Processing: 1390.jpg
# Processing: 1391.jpg
# Processing: 1392.jpg
# Processing: 1393.jpg
# Processing: 1394.jpg
# Processing: 1395.jpg
# Processing: 1396.jpg
# Processing: 1397.jpg
# Processing: 1398.jpg
# Processing: 1399.jpg
# Processing: 14.jpg
# Processing: 140.jpg
# Processing: 1400.jpg
# Processing: 1401.jpg
# Processing: 1402.jpg
# Processing: 1403.jpg
# Processing: 1404.jpg
# Processing: 1405.jpg
# Processing: 1406.jpg
# Processing: 1407.jpg
# Processing: 1408.jpg
# Processing: 1409.jpg
# Processing: 141.jpg
# Processing: 1410.jpg
# Processing: 1411.jpg
# Processing: 1412.jpg
# Processing: 1413.jpg
# Processing: 1414.jpg
# Processing: 1415.jpg
# Processing: 1416.jpg
# Processing: 1417.jpg
# Processing: 1418.jpg
# Processing: 1419.jpg
# Processing: 142.jpg
# Processing: 1420.jpg
# Processing: 1421.jpg
# Processing: 1422.jpg
# Processing: 1423.jpg
# Processing: 1424.jpg
# Processing: 1425.jpg
# Processing: 1426.jpg
# Processing: 1427.jpg
# Processing: 1428.jpg
# Processing: 1429.jpg
# Processing: 143.jpg
# Processing: 1430.jpg
# Processing: 1431.jpg
# Processing: 1432.jpg
# Processing: 1433.jpg
# Processing: 1434.jpg
# Processing: 1435.jpg
# Processing: 1436.jpg
# Processing: 1437.jpg
# Processing: 1438.jpg
# Processing: 1439.jpg
# Processing: 144.jpg
# Processing: 1440.jpg
# Processing: 1441.jpg
# Processing: 1442.jpg
# Processing: 1443.jpg
# Processing: 1444.jpg
# Processing: 1445.jpg
# Processing: 1446.jpg
# Processing: 1447.jpg
# Processing: 1448.jpg
# Processing: 1449.jpg
# Processing: 145.jpg
# Processing: 1450.jpg
# Processing: 1451.jpg
# Processing: 1452.jpg
# Processing: 1453.jpg
# Processing: 1454.jpg
# Processing: 1455.jpg
# Processing: 1456.jpg
# Processing: 1457.jpg
# Processing: 1458.jpg
# Processing: 1459.jpg
# Processing: 146.jpg
# Processing: 1460.jpg
# Processing: 1461.jpg
# Processing: 1462.jpg
# Processing: 1463.jpg
# Processing: 1464.jpg
# Processing: 1465.jpg
# Processing: 1466.jpg
# Processing: 1467.jpg
# Processing: 1468.jpg
# Processing: 1469.jpg
# Processing: 147.jpg
# Processing: 1470.jpg
# Processing: 1471.jpg
# Processing: 1472.jpg
# Processing: 1473.jpg
# Processing: 1474.jpg
# Processing: 1475.jpg
# Processing: 1476.jpg
# Processing: 1477.jpg
# Processing: 1478.jpg
# Processing: 1479.jpg
# Processing: 148.jpg
# Processing: 1480.jpg
# Processing: 1481.jpg
# Processing: 1482.jpg
# Processing: 1483.jpg
# Processing: 1484.jpg
# Processing: 1485.jpg
# Processing: 1486.jpg
# Processing: 1487.jpg
# Processing: 1488.jpg
# Processing: 1489.jpg
# Processing: 149.jpg
# Processing: 1490.jpg
# Processing: 1491.jpg
# Processing: 1492.jpg
# Processing: 1493.jpg
# Processing: 1494.jpg
# Processing: 1495.jpg
# Processing: 1496.jpg
# Processing: 1497.jpg
# Processing: 1498.jpg
# Processing: 1499.jpg
# Processing: 15.jpg
# Processing: 150.jpg
# Processing: 1500.jpg
# Processing: 1501.jpg
# Processing: 1502.jpg
# Processing: 1503.jpg
# Processing: 1504.jpg
# Processing: 1505.jpg
# Processing: 1506.jpg
# Processing: 1507.jpg
# Processing: 1508.jpg
# Processing: 1509.jpg
# Processing: 151.jpg
# Processing: 1510.jpg
# Processing: 1511.jpg
# Processing: 1512.jpg
# Processing: 1513.jpg
# Processing: 1514.jpg
# Processing: 1515.jpg
# Processing: 1516.jpg
# Processing: 1517.jpg
# Processing: 1518.jpg
# Processing: 1519.jpg
# Processing: 152.jpg
# Processing: 1520.jpg
# Processing: 1521.jpg
# Processing: 1522.jpg
# Processing: 1523.jpg
# Processing: 1524.jpg
# Processing: 1525.jpg
# Processing: 1526.jpg
# Processing: 1527.jpg
# Processing: 1528.jpg
# Processing: 1529.jpg
# Processing: 153.jpg
# Processing: 1530.jpg
# Processing: 1531.jpg
# Processing: 1532.jpg
# Processing: 1533.jpg
# Processing: 1534.jpg
# Processing: 1535.jpg
# Processing: 1536.jpg
# Processing: 1537.jpg
# Processing: 1538.jpg
# Processing: 1539.jpg
# Processing: 154.jpg
# Processing: 1540.jpg
# Processing: 1541.jpg
# Processing: 1542.jpg
# Processing: 1543.jpg
# Processing: 1544.jpg
# Processing: 1545.jpg
# Processing: 1546.jpg
# Processing: 1547.jpg
# Processing: 1548.jpg
# Processing: 1549.jpg
# Processing: 155.jpg
# Processing: 1550.jpg
# Processing: 1551.jpg
# Processing: 1552.jpg
# Processing: 1553.jpg
# Processing: 1554.jpg
# Processing: 1555.jpg
# Processing: 1556.jpg
# Processing: 1557.jpg
# Processing: 1558.jpg
# Processing: 1559.jpg
# Processing: 156.jpg
# Processing: 1560.jpg
# Processing: 1561.jpg
# Processing: 1562.jpg
# Processing: 1563.jpg
# Processing: 1564.jpg
# Processing: 1565.jpg
# Processing: 1566.jpg
# Processing: 1567.jpg
# Processing: 1568.jpg
# Processing: 1569.jpg
# Processing: 157.jpg
# Processing: 1570.jpg
# Processing: 1571.jpg
# Processing: 1572.jpg
# Processing: 1573.jpg
# Processing: 1574.jpg
# Processing: 1575.jpg
# Processing: 1576.jpg
# Processing: 1577.jpg
# Processing: 1578.jpg
# Processing: 1579.jpg
# Processing: 158.jpg
# Processing: 1580.jpg
# Processing: 1581.jpg
# Processing: 1582.jpg
# Processing: 1583.jpg
# Processing: 1584.jpg
# Processing: 1585.jpg
# Processing: 1586.jpg
# Processing: 1587.jpg
# Processing: 1588.jpg
# Processing: 1589.jpg
# Processing: 159.jpg
# Processing: 1590.jpg
# Processing: 1591.jpg
# Processing: 1592.jpg
# Processing: 1593.jpg
# Processing: 1594.jpg
# Processing: 1595.jpg
# Processing: 1596.jpg
# Processing: 1597.jpg
# Processing: 1598.jpg
# Processing: 1599.jpg
# Processing: 16.jpg
# Processing: 160.jpg
# Processing: 1600.jpg
# Processing: 1601.jpg
# Processing: 1602.jpg
# Processing: 1603.jpg
# Processing: 1604.jpg
# Processing: 1605.jpg
# Processing: 1606.jpg
# Processing: 1607.jpg
# Processing: 1608.jpg
# Processing: 1609.jpg
# Processing: 161.jpg
# Processing: 1610.jpg
# Processing: 1611.jpg
# Processing: 1612.jpg
# Processing: 1613.jpg
# Processing: 1614.jpg
# Processing: 1615.jpg
# Processing: 1616.jpg
# Processing: 1617.jpg
# Processing: 1618.jpg
# Processing: 1619.jpg
# Processing: 162.jpg
# Processing: 1620.jpg
# Processing: 1621.jpg
# Processing: 1622.jpg
# Processing: 1623.jpg
# Processing: 1624.jpg
# Processing: 1625.jpg
# Processing: 1626.jpg
# Processing: 1627.jpg
# Processing: 1628.jpg
# Processing: 1629.jpg
# Processing: 163.jpg
# Processing: 1630.jpg
# Processing: 1631.jpg
# Processing: 1632.jpg
# Processing: 1633.jpg
# Processing: 1634.jpg
# Processing: 1635.jpg
# Processing: 1636.jpg
# Processing: 1637.jpg
# Processing: 1638.jpg
# Processing: 1639.jpg
# Processing: 164.jpg
# Processing: 1640.jpg
# Processing: 1641.jpg
# Processing: 1642.jpg
# Processing: 1643.jpg
# Processing: 1644.jpg
# Processing: 1645.jpg
# Processing: 1646.jpg
# Processing: 1647.jpg
# Processing: 1648.jpg
# Processing: 1649.jpg
# Processing: 165.jpg
# Processing: 1650.jpg
# Processing: 1651.jpg
# Processing: 1652.jpg
# Processing: 1653.jpg
# Processing: 1654.jpg
# Processing: 1655.jpg
# Processing: 1656.jpg
# Processing: 1657.jpg
# Processing: 1658.jpg
# Processing: 1659.jpg
# Processing: 166.jpg
# Processing: 1660.jpg
# Processing: 1661.jpg
# Processing: 1662.jpg
# Processing: 1663.jpg
# Processing: 1664.jpg
# Processing: 1665.jpg
# Processing: 1666.jpg
# Processing: 1667.jpg
# Processing: 1668.jpg
# Processing: 1669.jpg
# Processing: 167.jpg
# Processing: 1670.jpg
# Processing: 1671.jpg
# Processing: 1672.jpg
# Processing: 1673.jpg
# Processing: 1674.jpg
# Processing: 1675.jpg
# Processing: 1676.jpg
# Processing: 1677.jpg
# Processing: 1678.jpg
# Processing: 1679.jpg
# Processing: 168.jpg
# Processing: 1680.jpg
# Processing: 1681.jpg
# Processing: 1682.jpg
# Processing: 1683.jpg
# Processing: 1684.jpg
# Processing: 1685.jpg
# Processing: 1686.jpg
# Processing: 1687.jpg
# Processing: 1688.jpg
# Processing: 1689.jpg
# Processing: 169.jpg
# Processing: 1690.jpg
# Processing: 1691.jpg
# Processing: 1692.jpg
# Processing: 1693.jpg
# Processing: 1694.jpg
# Processing: 1695.jpg
# Processing: 1696.jpg
# Processing: 1697.jpg
# Processing: 1698.jpg
# Processing: 1699.jpg
# Processing: 17.jpg
# Processing: 170.jpg
# Processing: 1700.jpg
# Processing: 1701.jpg
# Processing: 1702.jpg
# Processing: 1703.jpg
# Processing: 1704.jpg
# Processing: 1705.jpg
# Processing: 1706.jpg
# Processing: 1707.jpg
# Processing: 1708.jpg
# Processing: 1709.jpg
# Processing: 171.jpg
# Processing: 1710.jpg
# Processing: 1711.jpg
# Processing: 1712.jpg
# Processing: 1713.jpg
# Processing: 1714.jpg
# Processing: 1715.jpg
# Processing: 1716.jpg
# Processing: 1717.jpg
# Processing: 1718.jpg
# Processing: 1719.jpg
# Processing: 172.jpg
# Processing: 1720.jpg
# Processing: 1721.jpg
# Processing: 1722.jpg
# Processing: 1723.jpg
# Processing: 1724.jpg
# Processing: 1725.jpg
# Processing: 1726.jpg
# Processing: 1727.jpg
# Processing: 1728.jpg
# Processing: 1729.jpg
# Processing: 173.jpg
# Processing: 1730.jpg
# Processing: 1731.jpg
# Processing: 1732.jpg
# Processing: 1733.jpg
# Processing: 1734.jpg
# Processing: 1735.jpg
# Processing: 1736.jpg
# Processing: 1737.jpg
# Processing: 1738.jpg
# Processing: 1739.jpg
# Processing: 174.jpg
# Processing: 1740.jpg
# Processing: 1741.jpg
# Processing: 1742.jpg
# Processing: 1743.jpg
# Processing: 1744.jpg
# Processing: 1745.jpg
# Processing: 1746.jpg
# Processing: 1747.jpg
# Processing: 1748.jpg
# Processing: 1749.jpg
# Processing: 175.jpg
# Processing: 1750.jpg
# Processing: 1751.jpg
# Processing: 1752.jpg
# Processing: 1753.jpg
# Processing: 1754.jpg
# Processing: 1755.jpg
# Processing: 1756.jpg
# Processing: 1757.jpg
# Processing: 1758.jpg
# Processing: 1759.jpg
# Processing: 176.jpg
# Processing: 1760.jpg
# Processing: 1761.jpg
# Processing: 1762.jpg
# Processing: 1763.jpg
# Processing: 1764.jpg
# Processing: 1765.jpg
# Processing: 1766.jpg
# Processing: 1767.jpg
# Processing: 1768.jpg
# Processing: 1769.jpg
# Processing: 177.jpg
# Processing: 1770.jpg
# Processing: 1771.jpg
# Processing: 1772.jpg
# Processing: 1773.jpg
# Processing: 1774.jpg
# Processing: 1775.jpg
# Processing: 1776.jpg
# Processing: 1777.jpg
# Processing: 1778.jpg
# Processing: 1779.jpg
# Processing: 178.jpg
# Processing: 1780.jpg
# Processing: 1781.jpg
# Processing: 1782.jpg
# Processing: 1783.jpg
# Processing: 1784.jpg
# Processing: 1785.jpg
# Processing: 1786.jpg
# Processing: 1787.jpg
# Processing: 1788.jpg
# Processing: 1789.jpg
# Processing: 179.jpg
# Processing: 1790.jpg
# Processing: 1791.jpg
# Processing: 1792.jpg
# Processing: 1793.jpg
# Processing: 1794.jpg
# Processing: 1795.jpg
# Processing: 1796.jpg
# Processing: 1797.jpg
# Processing: 1798.jpg
# Processing: 1799.jpg
# Processing: 18.jpg
# Processing: 180.jpg
# Processing: 1800.jpg
# Processing: 1801.jpg
# Processing: 1802.jpg
# Processing: 1803.jpg
# Processing: 1804.jpg
# Processing: 1805.jpg
# Processing: 1806.jpg
# Processing: 1807.jpg
# Processing: 1808.jpg
# Processing: 1809.jpg
# Processing: 181.jpg
# Processing: 1810.jpg
# Processing: 1811.jpg
# Processing: 1812.jpg
# Processing: 1813.jpg
# Processing: 1814.jpg
# Processing: 1815.jpg
# Processing: 1816.jpg
# Processing: 1817.jpg
# Processing: 1818.jpg
# Processing: 1819.jpg
# Processing: 182.jpg
# Processing: 1820.jpg
# Processing: 1821.jpg
# Processing: 1822.jpg
# Processing: 1823.jpg
# Processing: 1824.jpg
# Processing: 1825.jpg
# Processing: 1826.jpg
# Processing: 1827.jpg
# Processing: 1828.jpg
# Processing: 1829.jpg
# Processing: 183.jpg
# Processing: 1830.jpg
# Processing: 1831.jpg
# Processing: 1832.jpg
# Processing: 1833.jpg
# Processing: 1834.jpg
# Processing: 1835.jpg
# Processing: 1836.jpg
# Processing: 1837.jpg
# Processing: 1838.jpg
# Processing: 1839.jpg
# Processing: 184.jpg
# Processing: 1840.jpg
# Processing: 1841.jpg
# Processing: 1842.jpg
# Processing: 1843.jpg
# Processing: 1844.jpg
# Processing: 1845.jpg
# Processing: 1846.jpg
# Processing: 1847.jpg
# Processing: 1848.jpg
# Processing: 1849.jpg
# Processing: 185.jpg
# Processing: 1850.jpg
# Processing: 1851.jpg
# Processing: 1852.jpg
# Processing: 1853.jpg
# Processing: 1854.jpg
# Processing: 1855.jpg
# Processing: 1856.jpg
# Processing: 1857.jpg
# Processing: 1858.jpg
# Processing: 1859.jpg
# Processing: 186.jpg
# Processing: 1860.jpg
# Processing: 1861.jpg
# Processing: 1862.jpg
# Processing: 1863.jpg
# Processing: 1864.jpg
# Processing: 1865.jpg
# Processing: 1866.jpg
# Processing: 1867.jpg
# Processing: 1868.jpg
# Processing: 1869.jpg
# Processing: 187.jpg
# Processing: 1870.jpg
# Processing: 1871.jpg
# Processing: 1872.jpg
# Processing: 1873.jpg
# Processing: 1874.jpg
# Processing: 1875.jpg
# Processing: 1876.jpg
# Processing: 1877.jpg
# Processing: 1878.jpg
# Processing: 1879.jpg
# Processing: 188.jpg
# Processing: 1880.jpg
# Processing: 1881.jpg
# Processing: 1882.jpg
# Processing: 1883.jpg
# Processing: 1884.jpg
# Processing: 1885.jpg
# Processing: 1886.jpg
# Processing: 1887.jpg
# Processing: 1888.jpg
# Processing: 1889.jpg
# Processing: 189.jpg
# Processing: 1890.jpg
# Processing: 1891.jpg
# Processing: 1892.jpg
# Processing: 1893.jpg
# Processing: 1894.jpg
# Processing: 1895.jpg
# Processing: 1896.jpg
# Processing: 1897.jpg
# Processing: 1898.jpg
# Processing: 1899.jpg
# Processing: 19.jpg
# Processing: 190.jpg
# Processing: 1900.jpg
# Processing: 1901.jpg
# Processing: 1902.jpg
# Processing: 1903.jpg
# Processing: 1904.jpg
# Processing: 1905.jpg
# Processing: 1906.jpg
# Processing: 1907.jpg
# Processing: 1908.jpg
# Processing: 1909.jpg
# Processing: 191.jpg
# Processing: 1910.jpg
# Processing: 1911.jpg
# Processing: 1912.jpg
# Processing: 1913.jpg
# Processing: 1914.jpg
# Processing: 1915.jpg
# Processing: 1916.jpg
# Processing: 1917.jpg
# Processing: 1918.jpg
# Processing: 1919.jpg
# Processing: 192.jpg
# Processing: 1920.jpg
# Processing: 1921.jpg
# Processing: 1922.jpg
# Processing: 1923.jpg
# Processing: 1924.jpg
# Processing: 1925.jpg
# Processing: 1926.jpg
# Processing: 1927.jpg
# Processing: 1928.jpg
# Processing: 1929.jpg
# Processing: 193.jpg
# Processing: 1930.jpg
# Processing: 1931.jpg
# Processing: 1932.jpg
# Processing: 1933.jpg
# Processing: 1934.jpg
# Processing: 1935.jpg
# Processing: 1936.jpg
# Processing: 1937.jpg
# Processing: 1938.jpg
# Processing: 1939.jpg
# Processing: 194.jpg
# Processing: 1940.jpg
# Processing: 1941.jpg
# Processing: 1942.jpg
# Processing: 1943.jpg
# Processing: 1944.jpg
# Processing: 1945.jpg
# Processing: 1946.jpg
# Processing: 1947.jpg
# Processing: 1948.jpg
# Processing: 1949.jpg
# Processing: 195.jpg
# Processing: 1950.jpg
# Processing: 1951.jpg
# Processing: 1952.jpg
# Processing: 1953.jpg
# Processing: 1954.jpg
# Processing: 1955.jpg
# Processing: 1956.jpg
# Processing: 1957.jpg
# Processing: 1958.jpg
# Processing: 1959.jpg
# Processing: 196.jpg
# Processing: 1960.jpg
# Processing: 1961.jpg
# Processing: 1962.jpg
# Processing: 1963.jpg
# Processing: 1964.jpg
# Processing: 1965.jpg
# Processing: 1966.jpg
# Processing: 1967.jpg
# Processing: 1968.jpg
# Processing: 1969.jpg
# Processing: 197.jpg
# Processing: 1970.jpg
# Processing: 1971.jpg
# Processing: 1972.jpg
# Processing: 1973.jpg
# Processing: 1974.jpg
# Processing: 1975.jpg
# Processing: 1976.jpg
# Processing: 1977.jpg
# Processing: 1978.jpg
# Processing: 1979.jpg
# Processing: 198.jpg
# Processing: 1980.jpg
# Processing: 1981.jpg
# Processing: 1982.jpg
# Processing: 1983.jpg
# Processing: 1984.jpg
# Processing: 1985.jpg
# Processing: 1986.jpg
# Processing: 1987.jpg
# Processing: 1988.jpg
# Processing: 1989.jpg
# Processing: 199.jpg
# Processing: 1990.jpg
# Processing: 1991.jpg
# Processing: 1992.jpg
# Processing: 1993.jpg
# Processing: 1994.jpg
# Processing: 1995.jpg
# Processing: 1996.jpg
# Processing: 1997.jpg
# Processing: 1998.jpg
# Processing: 1999.jpg
# Processing: 2.jpg
# Processing: 20.jpg
# Processing: 200.jpg
# Processing: 2000.jpg
# Processing: 2001.jpg
# Processing: 2002.jpg
# Processing: 2003.jpg
# Processing: 2004.jpg
# Processing: 2005.jpg
# Processing: 2006.jpg
# Processing: 2007.jpg
# Processing: 2008.jpg
# Processing: 2009.jpg
# Processing: 201.jpg
# Processing: 2010.jpg
# Processing: 2011.jpg
# Processing: 2012.jpg
# Processing: 2013.jpg
# Processing: 2014.jpg
# Processing: 2015.jpg
# Processing: 2016.jpg
# Processing: 2017.jpg
# Processing: 2018.jpg
# Processing: 2019.jpg
# Processing: 202.jpg
# Processing: 2020.jpg
# Processing: 2021.jpg
# Processing: 2022.jpg
# Processing: 2023.jpg
# Processing: 2024.jpg
# Processing: 2025.jpg
# Processing: 2026.jpg
# Processing: 2027.jpg
# Processing: 2028.jpg
# Processing: 2029.jpg
# Processing: 203.jpg
# Processing: 2030.jpg
# Processing: 2031.jpg
# Processing: 2032.jpg
# Processing: 2033.jpg
# Processing: 2034.jpg
# Processing: 2035.jpg
# Processing: 2036.jpg
# Processing: 2037.jpg
# Processing: 2038.jpg
# Processing: 2039.jpg
# Processing: 204.jpg
# Processing: 2040.jpg
# Processing: 2041.jpg
# Processing: 2042.jpg
# Processing: 2043.jpg
# Processing: 2044.jpg
# Processing: 2045.jpg
# Processing: 2046.jpg
# Processing: 2047.jpg
# Processing: 2048.jpg
# Processing: 2049.jpg
# Processing: 205.jpg
# Processing: 2050.jpg
# Processing: 2051.jpg
# Processing: 2052.jpg
# Processing: 2053.jpg
# Processing: 2054.jpg
# Processing: 2055.jpg
# Processing: 2056.jpg
# Processing: 2057.jpg
# Processing: 2058.jpg
# Processing: 2059.jpg
# Processing: 206.jpg
# Processing: 2060.jpg
# Processing: 2061.jpg
# Processing: 2062.jpg
# Processing: 2063.jpg
# Processing: 2064.jpg
# Processing: 2065.jpg
# Processing: 2066.jpg
# Processing: 2067.jpg
# Processing: 2068.jpg
# Processing: 2069.jpg
# Processing: 207.jpg
# Processing: 2070.jpg
# Processing: 2071.jpg
# Processing: 2072.jpg
# Processing: 2073.jpg
# Processing: 2074.jpg
# Processing: 2075.jpg
# Processing: 2076.jpg
# Processing: 2077.jpg
# Processing: 2078.jpg
# Processing: 2079.jpg
# Processing: 208.jpg
# Processing: 2080.jpg
# Processing: 2081.jpg
# Processing: 2082.jpg
# Processing: 2083.jpg
# Processing: 2084.jpg
# Processing: 2085.jpg
# Processing: 2086.jpg
# Processing: 2087.jpg
# Processing: 2088.jpg
# Processing: 2089.jpg
# Processing: 209.jpg
# Processing: 2090.jpg
# Processing: 2091.jpg
# Processing: 2092.jpg
# Processing: 2093.jpg
# Processing: 2094.jpg
# Processing: 2095.jpg
# Processing: 2096.jpg
# Processing: 2097.jpg
# Processing: 2098.jpg
# Processing: 2099.jpg
# Processing: 21.jpg
# Processing: 210.jpg
# Processing: 2100.jpg
# Processing: 2101.jpg
# Processing: 2102.jpg
# Processing: 2103.jpg
# Processing: 2104.jpg
# Processing: 2105.jpg
# Processing: 2106.jpg
# Processing: 2107.jpg
# Processing: 2108.jpg
# Processing: 2109.jpg
# Processing: 211.jpg
# Processing: 2110.jpg
# Processing: 2111.jpg
# Processing: 2112.jpg
# Processing: 2113.jpg
# Processing: 2114.jpg
# Processing: 2115.jpg
# Processing: 2116.jpg
# Processing: 2117.jpg
# Processing: 2118.jpg
# Processing: 2119.jpg
# Processing: 212.jpg
# Processing: 2120.jpg
# Processing: 2121.jpg
# Processing: 2122.jpg
# Processing: 2123.jpg
# Processing: 2124.jpg
# Processing: 2125.jpg
# Processing: 2126.jpg
# Processing: 2127.jpg
# Processing: 2128.jpg
# Processing: 2129.jpg
# Processing: 213.jpg
# Processing: 2130.jpg
# Processing: 2131.jpg
# Processing: 2132.jpg
# Processing: 2133.jpg
# Processing: 2134.jpg
# Processing: 2135.jpg
# Processing: 2136.jpg
# Processing: 2137.jpg
# Processing: 2138.jpg
# Processing: 2139.jpg
# Processing: 214.jpg
# Processing: 2140.jpg
# Processing: 2141.jpg
# Processing: 2142.jpg
# Processing: 2143.jpg
# Processing: 2144.jpg
# Processing: 2145.jpg
# Processing: 2146.jpg
# Processing: 2147.jpg
# Processing: 2148.jpg
# Processing: 2149.jpg
# Processing: 215.jpg
# Processing: 2150.jpg
# Processing: 2151.jpg
# Processing: 2152.jpg
# Processing: 2153.jpg
# Processing: 2154.jpg
# Processing: 2155.jpg
# Processing: 2156.jpg
# Processing: 2157.jpg
# Processing: 2158.jpg
# Processing: 2159.jpg
# Processing: 216.jpg
# Processing: 2160.jpg
# Processing: 2161.jpg
# Processing: 2162.jpg
# Processing: 2163.jpg
# Processing: 2164.jpg
# Processing: 2165.jpg
# Processing: 2166.jpg
# Processing: 2167.jpg
# Processing: 2168.jpg
# Processing: 2169.jpg
# Processing: 217.jpg
# Processing: 2170.jpg
# Processing: 2171.jpg
# Processing: 2172.jpg
# Processing: 2173.jpg
# Processing: 2174.jpg
# Processing: 2175.jpg
# Processing: 2176.jpg
# Processing: 2177.jpg
# Processing: 2178.jpg
# Processing: 2179.jpg
# Processing: 218.jpg
# Processing: 2180.jpg
# Processing: 2181.jpg
# Processing: 2182.jpg
# Processing: 2183.jpg
# Processing: 2184.jpg
# Processing: 2185.jpg
# Processing: 2186.jpg
# Processing: 2187.jpg
# Processing: 2188.jpg
# Processing: 2189.jpg
# Processing: 219.jpg
# Processing: 2190.jpg
# Processing: 2191.jpg
# Processing: 2192.jpg
# Processing: 2193.jpg
# Processing: 2194.jpg
# Processing: 2195.jpg
# Processing: 2196.jpg
# Processing: 2197.jpg
# Processing: 2198.jpg
# Processing: 2199.jpg
# Processing: 22.jpg
# Processing: 220.jpg
# Processing: 2200.jpg
# Processing: 2201.jpg
# Processing: 2202.jpg
# Processing: 2203.jpg
# Processing: 2204.jpg
# Processing: 2205.jpg
# Processing: 2206.jpg
# Processing: 2207.jpg
# Processing: 2208.jpg
# Processing: 2209.jpg
# Processing: 221.jpg
# Processing: 2210.jpg
# Processing: 2211.jpg
# Processing: 2212.jpg
# Processing: 2213.jpg
# Processing: 2214.jpg
# Processing: 2215.jpg
# Processing: 2216.jpg
# Processing: 2217.jpg
# Processing: 2218.jpg
# Processing: 2219.jpg
# Processing: 222.jpg
# Processing: 2220.jpg
# Processing: 2221.jpg
# Processing: 2222.jpg
# Processing: 2223.jpg
# Processing: 2224.jpg
# Processing: 2225.jpg
# Processing: 2226.jpg
# Processing: 2227.jpg
# Processing: 2228.jpg
# Processing: 2229.jpg
# Processing: 223.jpg
# Processing: 2230.jpg
# Processing: 2231.jpg
# Processing: 2232.jpg
# Processing: 2233.jpg
# Processing: 2234.jpg
# Processing: 2235.jpg
# Processing: 2236.jpg
# Processing: 2237.jpg
# Processing: 2238.jpg
# Processing: 2239.jpg
# Processing: 224.jpg
# Processing: 2240.jpg
# Processing: 2241.jpg
# Processing: 2242.jpg
# Processing: 2243.jpg
# Processing: 2244.jpg
# Processing: 2245.jpg
# Processing: 2246.jpg
# Processing: 2247.jpg
# Processing: 2248.jpg
# Processing: 2249.jpg
# Processing: 225.jpg
# Processing: 2250.jpg
# Processing: 2251.jpg
# Processing: 2252.jpg
# Processing: 2253.jpg
# Processing: 2254.jpg
# Processing: 2255.jpg
# Processing: 2256.jpg
# Processing: 2257.jpg
# Processing: 2258.jpg
# Processing: 2259.jpg
# Processing: 226.jpg
# Processing: 2260.jpg
# Processing: 2261.jpg
# Processing: 2262.jpg
# Processing: 2263.jpg
# Processing: 2264.jpg
# Processing: 2265.jpg
# Processing: 2266.jpg
# Processing: 2267.jpg
# Processing: 2268.jpg
# Processing: 2269.jpg
# Processing: 227.jpg
# Processing: 2270.jpg
# Processing: 2271.jpg
# Processing: 2272.jpg
# Processing: 2273.jpg
# Processing: 2274.jpg
# Processing: 2275.jpg
# Processing: 2276.jpg
# Processing: 2277.jpg
# Processing: 2278.jpg
# Processing: 2279.jpg
# Processing: 228.jpg
# Processing: 2280.jpg
# Processing: 2281.jpg
# Processing: 2282.jpg
# Processing: 2283.jpg
# Processing: 2284.jpg
# Processing: 2285.jpg
# Processing: 2286.jpg
# Processing: 2287.jpg
# Processing: 2288.jpg
# Processing: 2289.jpg
# Processing: 229.jpg
# Processing: 2290.jpg
# Processing: 2291.jpg
# Processing: 2292.jpg
# Processing: 2293.jpg
# Processing: 2294.jpg
# Processing: 2295.jpg
# Processing: 2296.jpg
# Processing: 2297.jpg
# Processing: 2298.jpg
# Processing: 2299.jpg
# Processing: 23.jpg
# Processing: 230.jpg
# Processing: 2300.jpg
# Processing: 2301.jpg
# Processing: 2302.jpg
# Processing: 2303.jpg
# Processing: 2304.jpg
# Processing: 2305.jpg
# Processing: 2306.jpg
# Processing: 2307.jpg
# Processing: 2308.jpg
# Processing: 2309.jpg
# Processing: 231.jpg
# Processing: 2310.jpg
# Processing: 2311.jpg
# Processing: 2312.jpg
# Processing: 2313.jpg
# Processing: 2314.jpg
# Processing: 2315.jpg
# Processing: 2316.jpg
# Processing: 2317.jpg
# Processing: 2318.jpg
# Processing: 2319.jpg
# Processing: 232.jpg
# Processing: 2320.jpg
# Processing: 2321.jpg
# Processing: 2322.jpg
# Processing: 2323.jpg
# Processing: 2324.jpg
# Processing: 2325.jpg
# Processing: 2326.jpg
# Processing: 2327.jpg
# Processing: 2328.jpg
# Processing: 2329.jpg
# Processing: 233.jpg
# Processing: 2330.jpg
# Processing: 2331.jpg
# Processing: 2332.jpg
# Processing: 2333.jpg
# Processing: 2334.jpg
# Processing: 2335.jpg
# Processing: 2336.jpg
# Processing: 2337.jpg
# Processing: 2338.jpg
# Processing: 2339.jpg
# Processing: 234.jpg
# Processing: 2340.jpg
# Processing: 2341.jpg
# Processing: 2342.jpg
# Processing: 2343.jpg
# Processing: 2344.jpg
# Processing: 2345.jpg
# Processing: 2346.jpg
# Processing: 2347.jpg
# Processing: 2348.jpg
# Processing: 2349.jpg
# Processing: 235.jpg
# Processing: 2350.jpg
# Processing: 2351.jpg
# Processing: 2352.jpg
# Processing: 2353.jpg
# Processing: 2354.jpg
# Processing: 2355.jpg
# Processing: 2356.jpg
# Processing: 2357.jpg
# Processing: 2358.jpg
# Processing: 2359.jpg
# Processing: 236.jpg
# Processing: 2360.jpg
# Processing: 2361.jpg
# Processing: 2362.jpg
# Processing: 2363.jpg
# Processing: 2364.jpg
# Processing: 2365.jpg
# Processing: 2366.jpg
# Processing: 2367.jpg
# Processing: 2368.jpg
# Processing: 2369.jpg
# Processing: 237.jpg
# Processing: 2370.jpg
# Processing: 2371.jpg
# Processing: 2372.jpg
# Processing: 2373.jpg
# Processing: 2374.jpg
# Processing: 2375.jpg
# Processing: 2376.jpg
# Processing: 2377.jpg
# Processing: 2378.jpg
# Processing: 2379.jpg
# Processing: 238.jpg
# Processing: 2380.jpg
# Processing: 2381.jpg
# Processing: 2382.jpg
# Processing: 2383.jpg
# Processing: 2384.jpg
# Processing: 2385.jpg
# Processing: 2386.jpg
# Processing: 2387.jpg
# Processing: 2388.jpg
# Processing: 2389.jpg
# Processing: 239.jpg
# Processing: 2390.jpg
# Processing: 2391.jpg
# Processing: 2392.jpg
# Processing: 2393.jpg
# Processing: 2394.jpg
# Processing: 2395.jpg
# Processing: 2396.jpg
# Processing: 2397.jpg
# Processing: 2398.jpg
# Processing: 2399.jpg
# Processing: 24.jpg
# Processing: 240.jpg
# Processing: 2400.jpg
# Processing: 2401.jpg
# Processing: 2402.jpg
# Processing: 2403.jpg
# Processing: 2404.jpg
# Processing: 2405.jpg
# Processing: 2406.jpg
# Processing: 2407.jpg
# Processing: 2408.jpg
# Processing: 2409.jpg
# Processing: 241.jpg
# Processing: 2410.jpg
# Processing: 2411.jpg
# Processing: 2412.jpg
# Processing: 2413.jpg
# Processing: 2414.jpg
# Processing: 2415.jpg
# Processing: 2416.jpg
# Processing: 2417.jpg
# Processing: 2418.jpg
# Processing: 2419.jpg
# Processing: 242.jpg
# Processing: 2420.jpg
# Processing: 2421.jpg
# Processing: 2422.jpg
# Processing: 2423.jpg
# Processing: 2424.jpg
# Processing: 2425.jpg
# Processing: 2426.jpg
# Processing: 2427.jpg
# Processing: 2428.jpg
# Processing: 2429.jpg
# Processing: 243.jpg
# Processing: 2430.jpg
# Processing: 2431.jpg
# Processing: 2432.jpg
# Processing: 2433.jpg
# Processing: 2434.jpg
# Processing: 2435.jpg
# Processing: 2436.jpg
# Processing: 2437.jpg
# Processing: 2438.jpg
# Processing: 2439.jpg
# Processing: 244.jpg
# Processing: 2440.jpg
# Processing: 2441.jpg
# Processing: 2442.jpg
# Processing: 2443.jpg
# Processing: 2444.jpg
# Processing: 2445.jpg
# Processing: 2446.jpg
# Processing: 2447.jpg
# Processing: 2448.jpg
# Processing: 2449.jpg
# Processing: 245.jpg
# Processing: 2450.jpg
# Processing: 2451.jpg
# Processing: 2452.jpg
# Processing: 2453.jpg
# Processing: 2454.jpg
# Processing: 2455.jpg
# Processing: 2456.jpg
# Processing: 2457.jpg
# Processing: 2458.jpg
# Processing: 2459.jpg
# Processing: 246.jpg
# Processing: 2460.jpg
# Processing: 2461.jpg
# Processing: 2462.jpg
# Processing: 2463.jpg
# Processing: 2464.jpg
# Processing: 2465.jpg
# Processing: 2466.jpg
# Processing: 2467.jpg
# Processing: 2468.jpg
# Processing: 2469.jpg
# Processing: 247.jpg
# Processing: 2470.jpg
# Processing: 2471.jpg
# Processing: 2472.jpg
# Processing: 2473.jpg
# Processing: 2474.jpg
# Processing: 2475.jpg
# Processing: 2476.jpg
# Processing: 2477.jpg
# Processing: 2478.jpg
# Processing: 2479.jpg
# Processing: 248.jpg
# Processing: 2480.jpg
# Processing: 2481.jpg
# Processing: 2482.jpg
# Processing: 2483.jpg
# Processing: 2484.jpg
# Processing: 2485.jpg
# Processing: 2486.jpg
# Processing: 2487.jpg
# Processing: 2488.jpg
# Processing: 2489.jpg
# Processing: 249.jpg
# Processing: 2490.jpg
# Processing: 2491.jpg
# Processing: 2492.jpg
# Processing: 2493.jpg
# Processing: 2494.jpg
# Processing: 2495.jpg
# Processing: 2496.jpg
# Processing: 2497.jpg
# Processing: 2498.jpg
# Processing: 2499.jpg
# Processing: 25.jpg
# Processing: 250.jpg
# Processing: 2500.jpg
# Processing: 2501.jpg
# Processing: 2502.jpg
# Processing: 2503.jpg
# Processing: 2504.jpg
# Processing: 2505.jpg
# Processing: 2506.jpg
# Processing: 2507.jpg
# Processing: 2508.jpg
# Processing: 2509.jpg
# Processing: 251.jpg
# Processing: 2510.jpg
# Processing: 2511.jpg
# Processing: 2512.jpg
# Processing: 2513.jpg
# Processing: 2514.jpg
# Processing: 2515.jpg
# Processing: 2516.jpg
# Processing: 2517.jpg
# Processing: 2518.jpg
# Processing: 2519.jpg
# Processing: 252.jpg
# Processing: 2520.jpg
# Processing: 2521.jpg
# Processing: 2522.jpg
# Processing: 2523.jpg
# Processing: 2524.jpg
# Processing: 2525.jpg
# Processing: 2526.jpg
# Processing: 2527.jpg
# Processing: 2528.jpg
# Processing: 2529.jpg
# Processing: 253.jpg
# Processing: 2530.jpg
# Processing: 2531.jpg
# Processing: 2532.jpg
# Processing: 2533.jpg
# Processing: 2534.jpg
# Processing: 2535.jpg
# Processing: 2536.jpg
# Processing: 2537.jpg
# Processing: 2538.jpg
# Processing: 2539.jpg
# Processing: 254.jpg
# Processing: 2540.jpg
# Processing: 2541.jpg
# Processing: 2542.jpg
# Processing: 2543.jpg
# Processing: 2544.jpg
# Processing: 2545.jpg
# Processing: 2546.jpg
# Processing: 2547.jpg
# Processing: 2548.jpg
# Processing: 2549.jpg
# Processing: 255.jpg
# Processing: 2550.jpg
# Processing: 2551.jpg
# Processing: 2552.jpg
# Processing: 2553.jpg
# Processing: 2554.jpg
# Processing: 2555.jpg
# Processing: 2556.jpg
# Processing: 2557.jpg
# Processing: 2558.jpg
# Processing: 2559.jpg
# Processing: 256.jpg
# Processing: 2560.jpg
# Processing: 2561.jpg
# Processing: 2562.jpg
# Processing: 2563.jpg
# Processing: 2564.jpg
# Processing: 2565.jpg
# Processing: 2566.jpg
# Processing: 2567.jpg
# Processing: 2568.jpg
# Processing: 2569.jpg
# Processing: 257.jpg
# Processing: 2570.jpg
# Processing: 2571.jpg
# Processing: 2572.jpg
# Processing: 2573.jpg
# Processing: 2574.jpg
# Processing: 2575.jpg
# Processing: 2576.jpg
# Processing: 2577.jpg
# Processing: 2578.jpg
# Processing: 2579.jpg
# Processing: 258.jpg
# Processing: 2580.jpg
# Processing: 2581.jpg
# Processing: 2582.jpg
# Processing: 2583.jpg
# Processing: 2584.jpg
# Processing: 2585.jpg
# Processing: 2586.jpg
# Processing: 2587.jpg
# Processing: 2588.jpg
# Processing: 2589.jpg
# Processing: 259.jpg
# Processing: 2590.jpg
# Processing: 2591.jpg
# Processing: 2592.jpg
# Processing: 2593.jpg
# Processing: 2594.jpg
# Processing: 2595.jpg
# Processing: 2596.jpg
# Processing: 2597.jpg
# Processing: 2598.jpg
# Processing: 2599.jpg
# Processing: 26.jpg
# Processing: 260.jpg
# Processing: 2600.jpg
# Processing: 2601.jpg
# Processing: 2602.jpg
# Processing: 2603.jpg
# Processing: 2604.jpg
# Processing: 2605.jpg
# Processing: 2606.jpg
# Processing: 2607.jpg
# Processing: 2608.jpg
# Processing: 2609.jpg
# Processing: 261.jpg
# Processing: 2610.jpg
# Processing: 2611.jpg
# Processing: 2612.jpg
# Processing: 2613.jpg
# Processing: 2614.jpg
# Processing: 2615.jpg
# Processing: 2616.jpg
# Processing: 2617.jpg
# Processing: 2618.jpg
# Processing: 2619.jpg
# Processing: 262.jpg
# Processing: 2620.jpg
# Processing: 2621.jpg
# Processing: 2622.jpg
# Processing: 2623.jpg
# Processing: 2624.jpg
# Processing: 2625.jpg
# Processing: 2626.jpg
# Processing: 2627.jpg
# Processing: 2628.jpg
# Processing: 2629.jpg
# Processing: 263.jpg
# Processing: 2630.jpg
# Processing: 2631.jpg
# Processing: 2632.jpg
# Processing: 2633.jpg
# Processing: 2634.jpg
# Processing: 2635.jpg
# Processing: 2636.jpg
# Processing: 2637.jpg
# Processing: 2638.jpg
# Processing: 2639.jpg
# Processing: 264.jpg
# Processing: 2640.jpg
# Processing: 2641.jpg
# Processing: 2642.jpg
# Processing: 2643.jpg
# Processing: 2644.jpg
# Processing: 2645.jpg
# Processing: 2646.jpg
# Processing: 2647.jpg
# Processing: 2648.jpg
# Processing: 2649.jpg
# Processing: 265.jpg
# Processing: 2650.jpg
# Processing: 2651.jpg
# Processing: 2652.jpg
# Processing: 2653.jpg
# Processing: 2654.jpg
# Processing: 2655.jpg
# Processing: 2656.jpg
# Processing: 2657.jpg
# Processing: 2658.jpg
# Processing: 2659.jpg
# Processing: 266.jpg
# Processing: 2660.jpg
# Processing: 2661.jpg
# Processing: 2662.jpg
# Processing: 2663.jpg
# Processing: 2664.jpg
# Processing: 2665.jpg
# Processing: 2666.jpg
# Processing: 2667.jpg
# Processing: 2668.jpg
# Processing: 2669.jpg
# Processing: 267.jpg
# Processing: 2670.jpg
# Processing: 2671.jpg
# Processing: 2672.jpg
# Processing: 2673.jpg
# Processing: 2674.jpg
# Processing: 2675.jpg
# Processing: 2676.jpg
# Processing: 2677.jpg
# Processing: 2678.jpg
# Processing: 2679.jpg
# Processing: 268.jpg
# Processing: 2680.jpg
# Processing: 2681.jpg
# Processing: 2682.jpg
# Processing: 2683.jpg
# Processing: 2684.jpg
# Processing: 2685.jpg
# Processing: 2686.jpg
# Processing: 2687.jpg
# Processing: 2688.jpg
# Processing: 2689.jpg
# Processing: 269.jpg
# Processing: 2690.jpg
# Processing: 2691.jpg
# Processing: 2692.jpg
# Processing: 2693.jpg
# Processing: 2694.jpg
# Processing: 2695.jpg
# Processing: 2696.jpg
# Processing: 2697.jpg
# Processing: 2698.jpg
# Processing: 2699.jpg
# Processing: 27.jpg
# Processing: 270.jpg
# Processing: 2700.jpg
# Processing: 2701.jpg
# Processing: 2702.jpg
# Processing: 2703.jpg
# Processing: 2704.jpg
# Processing: 2705.jpg
# Processing: 2706.jpg
# Processing: 2707.jpg
# Processing: 2708.jpg
# Processing: 2709.jpg
# Processing: 271.jpg
# Processing: 2710.jpg
# Processing: 2711.jpg
# Processing: 2712.jpg
# Processing: 2713.jpg
# Processing: 2714.jpg
# Processing: 2715.jpg
# Processing: 2716.jpg
# Processing: 2717.jpg
# Processing: 2718.jpg
# Processing: 2719.jpg
# Processing: 272.jpg
# Processing: 2720.jpg
# Processing: 2721.jpg
# Processing: 2722.jpg
# Processing: 2723.jpg
# Processing: 2724.jpg
# Processing: 2725.jpg
# Processing: 2726.jpg
# Processing: 2727.jpg
# Processing: 2728.jpg
# Processing: 2729.jpg
# Processing: 273.jpg
# Processing: 2730.jpg
# Processing: 2731.jpg
# Processing: 2732.jpg
# Processing: 2733.jpg
# Processing: 2734.jpg
# Processing: 2735.jpg
# Processing: 2736.jpg
# Processing: 2737.jpg
# Processing: 2738.jpg
# Processing: 2739.jpg
# Processing: 274.jpg
# Processing: 2740.jpg
# Processing: 2741.jpg
# Processing: 2742.jpg
# Processing: 2743.jpg
# Processing: 2744.jpg
# Processing: 2745.jpg
# Processing: 2746.jpg
# Processing: 2747.jpg
# Processing: 2748.jpg
# Processing: 2749.jpg
# Processing: 275.jpg
# Processing: 2750.jpg
# Processing: 2751.jpg
# Processing: 2752.jpg
# Processing: 2753.jpg
# Processing: 2754.jpg
# Processing: 2755.jpg
# Processing: 2756.jpg
# Processing: 2757.jpg
# Processing: 2758.jpg
# Processing: 2759.jpg
# Processing: 276.jpg
# Processing: 2760.jpg
# Processing: 2761.jpg
# Processing: 2762.jpg
# Processing: 2763.jpg
# Processing: 2764.jpg
# Processing: 2765.jpg
# Processing: 2766.jpg
# Processing: 2767.jpg
# Processing: 2768.jpg
# Processing: 2769.jpg
# Processing: 277.jpg
# Processing: 2770.jpg
# Processing: 2771.jpg
# Processing: 2772.jpg
# Processing: 2773.jpg
# Processing: 2774.jpg
# Processing: 2775.jpg
# Processing: 2776.jpg
# Processing: 2777.jpg
# Processing: 2778.jpg
# Processing: 2779.jpg
# Processing: 278.jpg
# Processing: 2780.jpg
# Processing: 2781.jpg
# Processing: 2782.jpg
# Processing: 2783.jpg
# Processing: 2784.jpg
# Processing: 2785.jpg
# Processing: 2786.jpg
# Processing: 2787.jpg
# Processing: 2788.jpg
# Processing: 2789.jpg
# Processing: 279.jpg
# Processing: 2790.jpg
# Processing: 2791.jpg
# Processing: 2792.jpg
# Processing: 2793.jpg
# Processing: 2794.jpg
# Processing: 2795.jpg
# Processing: 2796.jpg
# Processing: 2797.jpg
# Processing: 2798.jpg
# Processing: 2799.jpg
# Processing: 28.jpg
# Processing: 280.jpg
# Processing: 2800.jpg
# Processing: 2801.jpg
# Processing: 2802.jpg
# Processing: 2803.jpg
# Processing: 2804.jpg
# Processing: 2805.jpg
# Processing: 2806.jpg
# Processing: 2807.jpg
# Processing: 2808.jpg
# Processing: 2809.jpg
# Processing: 281.jpg
# Processing: 2810.jpg
# Processing: 2811.jpg
# Processing: 2812.jpg
# Processing: 2813.jpg
# Processing: 2814.jpg
# Processing: 2815.jpg
# Processing: 2816.jpg
# Processing: 2817.jpg
# Processing: 2818.jpg
# Processing: 2819.jpg
# Processing: 282.jpg
# Processing: 2820.jpg
# Processing: 2821.jpg
# Processing: 2822.jpg
# Processing: 2823.jpg
# Processing: 2824.jpg
# Processing: 2825.jpg
# Processing: 2826.jpg
# Processing: 2827.jpg
# Processing: 2828.jpg
# Processing: 2829.jpg
# Processing: 283.jpg
# Processing: 2830.jpg
# Processing: 2831.jpg
# Processing: 2832.jpg
# Processing: 2833.jpg
# Processing: 2834.jpg
# Processing: 2835.jpg
# Processing: 2836.jpg
# Processing: 2837.jpg
# Processing: 2838.jpg
# Processing: 2839.jpg
# Processing: 284.jpg
# Processing: 2840.jpg
# Processing: 2841.jpg
# Processing: 2842.jpg
# Processing: 2843.jpg
# Processing: 2844.jpg
# Processing: 2845.jpg
# Processing: 2846.jpg
# Processing: 2847.jpg
# Processing: 2848.jpg
# Processing: 2849.jpg
# Processing: 285.jpg
# Processing: 2850.jpg
# Processing: 2851.jpg
# Processing: 2852.jpg
# Processing: 2853.jpg
# Processing: 2854.jpg
# Processing: 2855.jpg
# Processing: 2856.jpg
# Processing: 2857.jpg
# Processing: 2858.jpg
# Processing: 2859.jpg
# Processing: 286.jpg
# Processing: 2860.jpg
# Processing: 2861.jpg
# Processing: 2862.jpg
# Processing: 2863.jpg
# Processing: 2864.jpg
# Processing: 2865.jpg
# Processing: 2866.jpg
# Processing: 2867.jpg
# Processing: 2868.jpg
# Processing: 2869.jpg
# Processing: 287.jpg
# Processing: 2870.jpg
# Processing: 2871.jpg
# Processing: 2872.jpg
# Processing: 2873.jpg
# Processing: 2874.jpg
# Processing: 2875.jpg
# Processing: 2876.jpg
# Processing: 2877.jpg
# Processing: 2878.jpg
# Processing: 2879.jpg
# Processing: 288.jpg
# Processing: 2880.jpg
# Processing: 2881.jpg
# Processing: 2882.jpg
# Processing: 2883.jpg
# Processing: 2884.jpg
# Processing: 2885.jpg
# Processing: 2886.jpg
# Processing: 2887.jpg
# Processing: 2888.jpg
# Processing: 2889.jpg
# Processing: 289.jpg
# Processing: 2890.jpg
# Processing: 2891.jpg
# Processing: 2892.jpg
# Processing: 2893.jpg
# Processing: 2894.jpg
# Processing: 2895.jpg
# Processing: 2896.jpg
# Processing: 2897.jpg
# Processing: 2898.jpg
# Processing: 2899.jpg
# Processing: 29.jpg
# Processing: 290.jpg
# Processing: 2900.jpg
# Processing: 2901.jpg
# Processing: 2902.jpg
# Processing: 2903.jpg
# Processing: 2904.jpg
# Processing: 2905.jpg
# Processing: 2906.jpg
# Processing: 2907.jpg
# Processing: 2908.jpg
# Processing: 2909.jpg
# Processing: 291.jpg
# Processing: 2910.jpg
# Processing: 2911.jpg
# Processing: 2912.jpg
# Processing: 2913.jpg
# Processing: 2914.jpg
# Processing: 2915.jpg
# Processing: 2916.jpg
# Processing: 2917.jpg
# Processing: 2918.jpg
# Processing: 2919.jpg
# Processing: 292.jpg
# Processing: 2920.jpg
# Processing: 2921.jpg
# Processing: 2922.jpg
# Processing: 2923.jpg
# Processing: 2924.jpg
# Processing: 2925.jpg
# Processing: 2926.jpg
# Processing: 2927.jpg
# Processing: 2928.jpg
# Processing: 2929.jpg
# Processing: 293.jpg
# Processing: 2930.jpg
# Processing: 2931.jpg
# Processing: 2932.jpg
# Processing: 2933.jpg
# Processing: 2934.jpg
# Processing: 2935.jpg
# Processing: 2936.jpg
# Processing: 2937.jpg
# Processing: 2938.jpg
# Processing: 2939.jpg
# Processing: 294.jpg
# Processing: 2940.jpg
# Processing: 2941.jpg
# Processing: 2942.jpg
# Processing: 2943.jpg
# Processing: 2944.jpg
# Processing: 2945.jpg
# Processing: 2946.jpg
# Processing: 2947.jpg
# Processing: 2948.jpg
# Processing: 2949.jpg
# Processing: 295.jpg
# Processing: 2950.jpg
# Processing: 2951.jpg
# Processing: 2952.jpg
# Processing: 2953.jpg
# Processing: 2954.jpg
# Processing: 2955.jpg
# Processing: 2956.jpg
# Processing: 2957.jpg
# Processing: 2958.jpg
# Processing: 2959.jpg
# Processing: 296.jpg
# Processing: 2960.jpg
# Processing: 2961.jpg
# Processing: 2962.jpg
# Processing: 2963.jpg
# Processing: 2964.jpg
# Processing: 2965.jpg
# Processing: 2966.jpg
# Processing: 2967.jpg
# Processing: 2968.jpg
# Processing: 2969.jpg
# Processing: 297.jpg
# Processing: 2970.jpg
# Processing: 2971.jpg
# Processing: 2972.jpg
# Processing: 2973.jpg
# Processing: 2974.jpg
# Processing: 2975.jpg
# Processing: 2976.jpg
# Processing: 2977.jpg
# Processing: 2978.jpg
# Processing: 2979.jpg
# Processing: 298.jpg
# Processing: 2980.jpg
# Processing: 2981.jpg
# Processing: 2982.jpg
# Processing: 2983.jpg
# Processing: 2984.jpg
# Processing: 2985.jpg
# Processing: 2986.jpg
# Processing: 2987.jpg
# Processing: 2988.jpg
# Processing: 2989.jpg
# Processing: 299.jpg
# Processing: 2990.jpg
# Processing: 2991.jpg
# Processing: 2992.jpg
# Processing: 2993.jpg
# Processing: 2994.jpg
# Processing: 2995.jpg
# Processing: 2996.jpg
# Processing: 2997.jpg
# Processing: 2998.jpg
# Processing: 2999.jpg
# Processing: 3.jpg
# Processing: 30.jpg
# Processing: 300.jpg
# Processing: 3000.jpg
# Processing: 3001.jpg
# Processing: 3002.jpg
# Processing: 3003.jpg
# Processing: 3004.jpg
# Processing: 3005.jpg
# Processing: 3006.jpg
# Processing: 3007.jpg
# Processing: 3008.jpg
# Processing: 3009.jpg
# Processing: 301.jpg
# Processing: 3010.jpg
# Processing: 3011.jpg
# Processing: 3012.jpg
# Processing: 3013.jpg
# Processing: 3014.jpg
# Processing: 3015.jpg
# Processing: 3016.jpg
# Processing: 3017.jpg
# Processing: 3018.jpg
# Processing: 3019.jpg
# Processing: 302.jpg
# Processing: 3020.jpg
# Processing: 3021.jpg
# Processing: 3022.jpg
# Processing: 3023.jpg
# Processing: 3024.jpg
# Processing: 3025.jpg
# Processing: 3026.jpg
# Processing: 3027.jpg
# Processing: 3028.jpg
# Processing: 3029.jpg
# Processing: 303.jpg
# Processing: 3030.jpg
# Processing: 3031.jpg
# Processing: 3032.jpg
# Processing: 3033.jpg
# Processing: 3034.jpg
# Processing: 3035.jpg
# Processing: 3036.jpg
# Processing: 3037.jpg
# Processing: 3038.jpg
# Processing: 3039.jpg
# Processing: 304.jpg
# Processing: 3040.jpg
# Processing: 3041.jpg
# Processing: 3042.jpg
# Processing: 3043.jpg
# Processing: 3044.jpg
# Processing: 3045.jpg
# Processing: 3046.jpg
# Processing: 3047.jpg
# Processing: 3048.jpg
# Processing: 3049.jpg
# Processing: 305.jpg
# Processing: 3050.jpg
# Processing: 3051.jpg
# Processing: 3052.jpg
# Processing: 3053.jpg
# Processing: 3054.jpg
# Processing: 3055.jpg
# Processing: 3056.jpg
# Processing: 3057.jpg
# Processing: 3058.jpg
# Processing: 3059.jpg
# Processing: 306.jpg
# Processing: 3060.jpg
# Processing: 3061.jpg
# Processing: 3062.jpg
# Processing: 3063.jpg
# Processing: 3064.jpg
# Processing: 3065.jpg
# Processing: 3066.jpg
# ...
# Processing: 278.jpg
# Processing: 279.jpg
# Processing: 28.jpg
# Processing: 280.jpg
# Processing: 281.jpg
# Processing: 282.jpg
# Processing: 283.jpg
# Processing: 284.jpg
# Processing: 285.jpg
# Processing: 286.jpg
# Processing: 287.jpg
# Processing: 288.jpg
# Processing: 289.jpg
# Processing: 29.jpg
# Processing: 290.jpg
# Processing: 291.jpg
# Processing: 292.jpg
# Processing: 293.jpg
# Processing: 294.jpg
# Processing: 295.jpg
# Processing: 296.jpg
# Processing: 297.jpg
# Processing: 298.jpg
# Processing: 299.jpg
# Processing: 3.jpg
# Processing: 30.jpg
# Processing: 300.jpg
# Processing: 301.jpg
# Processing: 302.jpg
# Processing: 303.jpg
# Processing: 304.jpg
# Processing: 305.jpg
# Processing: 306.jpg
# Processing: 307.jpg
# Processing: 308.jpg
# Processing: 309.jpg
# Processing: 31.jpg
# Processing: 310.jpg
# Processing: 311.jpg
# Processing: 312.jpg
# Processing: 313.jpg
# Processing: 314.jpg
# Processing: 315.jpg
# Processing: 316.jpg
# Processing: 317.jpg
# Processing: 318.jpg
# Processing: 319.jpg
# Processing: 32.jpg
# Processing: 320.jpg
# Processing: 321.jpg
# Processing: 322.jpg
# Processing: 323.jpg
# Processing: 324.jpg
# Processing: 325.jpg
# Processing: 326.jpg
# Processing: 327.jpg
# Processing: 328.jpg
# Processing: 329.jpg
# Processing: 33.jpg
# Processing: 330.jpg
# Processing: 331.jpg
# Processing: 332.jpg
# Processing: 333.jpg
# Processing: 334.jpg
# Processing: 335.jpg
# Processing: 336.jpg
# Processing: 337.jpg
# Processing: 338.jpg
# Processing: 339.jpg
# Processing: 34.jpg
# Processing: 340.jpg
# Processing: 341.jpg
# Processing: 342.jpg
# Processing: 343.jpg
# Processing: 344.jpg
# Processing: 345.jpg
# Processing: 346.jpg
# Processing: 347.jpg
# Processing: 348.jpg
# Processing: 349.jpg
# Processing: 35.jpg
# Processing: 350.jpg
# Processing: 351.jpg
# Processing: 352.jpg
# Processing: 353.jpg
# Processing: 354.jpg
# Processing: 355.jpg
# Processing: 356.jpg
# Processing: 357.jpg
# Processing: 358.jpg
# Processing: 359.jpg
# Processing: 36.jpg
# Processing: 360.jpg
# Processing: 361.jpg
# Processing: 362.jpg
# Processing: 363.jpg
# Processing: 364.jpg
# Processing: 365.jpg
# Processing: 366.jpg
# Processing: 367.jpg
# Processing: 368.jpg
# Processing: 369.jpg
# Processing: 37.jpg
# Processing: 370.jpg
# Processing: 371.jpg
# Processing: 372.jpg
# Processing: 373.jpg
# Processing: 374.jpg
# Processing: 375.jpg
# Processing: 376.jpg
# Processing: 377.jpg
# Processing: 378.jpg
# Processing: 379.jpg
# Processing: 38.jpg
# Processing: 380.jpg
# Processing: 381.jpg
# Processing: 382.jpg
# Processing: 383.jpg
# Processing: 384.jpg
# Processing: 385.jpg
# Processing: 386.jpg
# Processing: 387.jpg
# Processing: 388.jpg
# Processing: 389.jpg
# Processing: 39.jpg
# Processing: 390.jpg
# Processing: 391.jpg
# Processing: 392.jpg
# Processing: 393.jpg
# Processing: 394.jpg
# Processing: 395.jpg
# Processing: 396.jpg
# Processing: 397.jpg
# Processing: 398.jpg
# Processing: 399.jpg
# Processing: 4.jpg
# Processing: 40.jpg
# Processing: 400.jpg
# Processing: 401.jpg
# Processing: 402.jpg
# Processing: 403.jpg
# Processing: 404.jpg
# Processing: 405.jpg
# Processing: 406.jpg
# Processing: 407.jpg
# Processing: 408.jpg
# Processing: 409.jpg
# Processing: 41.jpg
# Processing: 410.jpg
# Processing: 411.jpg
# Processing: 412.jpg
# Processing: 413.jpg
# Processing: 414.jpg
# Processing: 415.jpg
# Processing: 416.jpg
# Processing: 417.jpg
# Processing: 418.jpg
# Processing: 419.jpg
# Processing: 42.jpg
# Processing: 420.jpg
# Processing: 421.jpg
# Processing: 422.jpg
# Processing: 423.jpg
# Processing: 424.jpg
# Processing: 425.jpg
# Processing: 426.jpg
# Processing: 427.jpg
# Processing: 428.jpg
# Processing: 429.jpg
# Processing: 43.jpg
# Processing: 430.jpg
# Processing: 431.jpg
# Processing: 432.jpg
# Processing: 433.jpg
# Processing: 434.jpg
# Processing: 435.jpg
# Processing: 436.jpg
# Processing: 437.jpg
# Processing: 438.jpg
# Processing: 439.jpg
# Processing: 44.jpg
# Processing: 440.jpg
# Processing: 441.jpg
# Processing: 442.jpg
# Processing: 443.jpg
# Processing: 444.jpg
# Processing: 445.jpg
# Processing: 446.jpg
# Processing: 447.jpg
# Processing: 448.jpg
# Processing: 449.jpg
# Processing: 45.jpg
# Processing: 450.jpg
# Processing: 451.jpg
# Processing: 452.jpg
# Processing: 453.jpg
# Processing: 454.jpg
# Processing: 455.jpg
# Processing: 456.jpg
# Processing: 457.jpg
# Processing: 458.jpg
# Processing: 459.jpg
# Processing: 46.jpg
# Processing: 460.jpg
# Processing: 461.jpg
# Processing: 462.jpg
# Processing: 463.jpg
# Processing: 464.jpg
# Processing: 465.jpg
# Processing: 466.jpg
# Processing: 467.jpg
# Processing: 468.jpg
# Processing: 469.jpg
# Processing: 47.jpg
# Processing: 470.jpg
# Processing: 471.jpg
# Processing: 472.jpg
# Processing: 473.jpg
# Processing: 474.jpg
# Processing: 475.jpg
# Processing: 476.jpg
# Processing: 477.jpg
# Processing: 478.jpg
# Processing: 479.jpg
# Processing: 48.jpg
# Processing: 480.jpg
# Processing: 481.jpg
# Processing: 482.jpg
# Processing: 483.jpg
# Processing: 484.jpg
# Processing: 485.jpg
# Processing: 486.jpg
# Processing: 487.jpg
# Processing: 488.jpg
# Processing: 489.jpg
# Processing: 49.jpg
# Processing: 490.jpg
# Processing: 491.jpg
# Processing: 492.jpg
# Processing: 493.jpg
# Processing: 494.jpg
# Processing: 495.jpg
# Processing: 496.jpg
# Processing: 497.jpg
# Processing: 498.jpg
# Processing: 499.jpg
# Processing: 5.jpg
# Processing: 50.jpg
# Processing: 500.jpg
# Processing: 501.jpg
# Processing: 502.jpg
# Processing: 503.jpg
# Processing: 504.jpg
# Processing: 505.jpg
# Processing: 506.jpg
# Processing: 507.jpg
# Processing: 508.jpg
# Processing: 509.jpg
# Processing: 51.jpg
# Processing: 510.jpg
# Processing: 511.jpg
# Processing: 512.jpg
# Processing: 513.jpg
# Processing: 514.jpg
# Processing: 515.jpg
# Processing: 516.jpg
# Processing: 517.jpg
# Processing: 518.jpg
# Processing: 519.jpg
# Processing: 52.jpg
# Processing: 520.jpg
# Processing: 521.jpg
# Processing: 522.jpg
# Processing: 523.jpg
# Processing: 524.jpg
# Processing: 525.jpg
# Processing: 526.jpg
# Processing: 527.jpg
# Processing: 528.jpg
# Processing: 529.jpg
# Processing: 53.jpg
# Processing: 530.jpg
# Processing: 531.jpg
# Processing: 532.jpg
# Processing: 533.jpg
# Processing: 534.jpg
# Processing: 535.jpg
# Processing: 536.jpg
# Processing: 537.jpg
# Processing: 538.jpg
# Processing: 539.jpg
# Processing: 54.jpg
# Processing: 540.jpg
# Processing: 541.jpg
# Processing: 542.jpg
# Processing: 543.jpg
# Processing: 544.jpg
# Processing: 545.jpg
# Processing: 546.jpg
# Processing: 547.jpg
# Processing: 548.jpg
# Processing: 549.jpg
# Processing: 55.jpg
# Processing: 550.jpg
# Processing: 551.jpg
# Processing: 552.jpg
# Processing: 553.jpg
# Processing: 554.jpg
# Processing: 555.jpg
# Processing: 556.jpg
# Processing: 557.jpg
# Processing: 558.jpg
# Processing: 559.jpg
# Processing: 56.jpg
# Processing: 560.jpg
# Processing: 561.jpg
# Processing: 562.jpg
# Processing: 563.jpg
# Processing: 564.jpg
# Processing: 565.jpg
# Processing: 566.jpg
# Processing: 567.jpg
# Processing: 568.jpg
# Processing: 569.jpg
# Processing: 57.jpg
# Processing: 570.jpg
# Processing: 571.jpg
# Processing: 572.jpg
# Processing: 573.jpg
# Processing: 574.jpg
# Processing: 575.jpg
# Processing: 576.jpg
# Processing: 577.jpg
# Processing: 578.jpg
# Processing: 579.jpg
# Processing: 58.jpg
# Processing: 580.jpg
# Processing: 581.jpg
# Processing: 582.jpg
# Processing: 583.jpg
# Processing: 584.jpg
# Processing: 585.jpg
# Processing: 586.jpg
# Processing: 587.jpg
# Processing: 588.jpg
# Processing: 589.jpg
# Processing: 59.jpg
# Processing: 590.jpg
# Processing: 591.jpg
# Processing: 592.jpg
# Processing: 593.jpg
# Processing: 594.jpg
# Processing: 595.jpg
# Processing: 596.jpg
# Processing: 597.jpg
# Processing: 598.jpg
# Processing: 599.jpg
# Processing: 6.jpg
# Processing: 60.jpg
# Processing: 600.jpg
# Processing: 601.jpg
# Processing: 602.jpg
# Processing: 603.jpg
# Processing: 604.jpg
# Processing: 605.jpg
# Processing: 606.jpg
# Processing: 607.jpg
# Processing: 608.jpg
# Processing: 609.jpg
# Processing: 61.jpg
# Processing: 610.jpg
# Processing: 611.jpg
# Processing: 612.jpg
# Processing: 613.jpg
# Processing: 614.jpg
# Processing: 615.jpg
# Processing: 616.jpg
# Processing: 617.jpg
# Processing: 618.jpg
# Processing: 619.jpg
# Processing: 62.jpg
# Processing: 620.jpg
# Processing: 621.jpg
# Processing: 622.jpg
# Processing: 623.jpg
# Processing: 624.jpg
# Processing: 625.jpg
# Processing: 626.jpg
# Processing: 627.jpg
# Processing: 628.jpg
# Processing: 629.jpg
# Processing: 63.jpg
# Processing: 630.jpg
# Processing: 631.jpg
# Processing: 632.jpg
# Processing: 633.jpg
# Processing: 634.jpg
# Processing: 635.jpg
# Processing: 636.jpg
# Processing: 637.jpg
# Processing: 638.jpg
# Processing: 639.jpg
# Processing: 64.jpg
# Processing: 640.jpg
# Processing: 641.jpg
# Processing: 642.jpg
# Processing: 643.jpg
# Processing: 644.jpg
# Processing: 645.jpg
# Processing: 646.jpg
# Processing: 647.jpg
# Processing: 648.jpg
# Processing: 649.jpg
# Processing: 65.jpg
# Processing: 650.jpg
# Processing: 651.jpg
# Processing: 652.jpg
# Processing: 653.jpg
# Processing: 654.jpg
# Processing: 655.jpg
# Processing: 656.jpg
# Processing: 657.jpg
# Processing: 658.jpg
# Processing: 659.jpg
# Processing: 66.jpg
# Processing: 660.jpg
# Processing: 661.jpg
# Processing: 662.jpg
# Processing: 663.jpg
# Processing: 664.jpg
# Processing: 665.jpg
# Processing: 666.jpg
# Processing: 667.jpg
# Processing: 668.jpg
# Processing: 669.jpg
# Processing: 67.jpg
# Processing: 670.jpg
# Processing: 671.jpg
# Processing: 672.jpg
# Processing: 673.jpg
# Processing: 674.jpg
# Processing: 675.jpg
# Processing: 676.jpg
# Processing: 677.jpg
# Processing: 678.jpg
# Processing: 679.jpg
# Processing: 68.jpg
# Processing: 680.jpg
# Processing: 681.jpg
# Processing: 682.jpg
# Processing: 683.jpg
# Processing: 684.jpg
# Processing: 685.jpg
# Processing: 686.jpg
# Processing: 687.jpg
# Processing: 688.jpg
# Processing: 689.jpg
# Processing: 69.jpg
# Processing: 690.jpg
# Processing: 691.jpg
# Processing: 692.jpg
# Processing: 693.jpg
# Processing: 694.jpg
# Processing: 695.jpg
# Processing: 696.jpg
# Processing: 697.jpg
# Processing: 698.jpg
# Processing: 699.jpg
# Processing: 7.jpg
# Processing: 70.jpg
# Processing: 700.jpg
# Processing: 701.jpg
# Processing: 702.jpg
# Processing: 703.jpg
# Processing: 704.jpg
# Processing: 705.jpg
# Processing: 706.jpg
# Processing: 707.jpg
# Processing: 708.jpg
# Processing: 709.jpg
# Processing: 71.jpg
# Processing: 710.jpg
# Processing: 711.jpg
# Processing: 712.jpg
# Processing: 713.jpg
# Processing: 714.jpg
# Processing: 715.jpg
# Processing: 716.jpg
# Processing: 717.jpg
# Processing: 718.jpg
# Processing: 719.jpg
# Processing: 72.jpg
# Processing: 720.jpg
# Processing: 721.jpg
# Processing: 722.jpg
# Processing: 723.jpg
# Processing: 724.jpg
# Processing: 725.jpg
# Processing: 726.jpg
# Processing: 727.jpg
# Processing: 728.jpg
# Processing: 729.jpg
# Processing: 73.jpg
# Processing: 730.jpg
# Processing: 731.jpg
# Processing: 732.jpg
# Processing: 733.jpg
# Processing: 734.jpg
# Processing: 735.jpg
# Processing: 736.jpg
# Processing: 737.jpg
# Processing: 738.jpg
# Processing: 739.jpg
# Processing: 74.jpg
# Processing: 740.jpg
# Processing: 741.jpg
# Processing: 742.jpg
# Processing: 743.jpg
# Processing: 744.jpg
# Processing: 745.jpg
# Processing: 746.jpg
# Processing: 747.jpg
# Processing: 748.jpg
# Processing: 749.jpg
# Processing: 75.jpg
# Processing: 750.jpg
# Processing: 751.jpg
# Processing: 752.jpg
# Processing: 753.jpg
# Processing: 754.jpg
# Processing: 755.jpg
# Processing: 756.jpg
# Processing: 757.jpg
# Processing: 758.jpg
# Processing: 759.jpg
# Processing: 76.jpg
# Processing: 760.jpg
# Processing: 761.jpg
# Processing: 762.jpg
# Processing: 763.jpg
# Processing: 764.jpg
# Processing: 765.jpg
# Processing: 766.jpg
# Processing: 767.jpg
# Processing: 768.jpg
# Processing: 769.jpg
# Processing: 77.jpg
# Processing: 770.jpg
# Processing: 771.jpg
# Processing: 772.jpg
# Processing: 773.jpg
# Processing: 774.jpg
# Processing: 775.jpg
# Processing: 776.jpg
# Processing: 777.jpg
# Processing: 778.jpg
# Processing: 779.jpg
# Processing: 78.jpg
# Processing: 780.jpg
# Processing: 781.jpg
# Processing: 782.jpg
# Processing: 783.jpg
# Processing: 784.jpg
# Processing: 785.jpg
# Processing: 786.jpg
# Processing: 787.jpg
# Processing: 788.jpg
# Processing: 789.jpg
# Processing: 79.jpg
# Processing: 790.jpg
# Processing: 791.jpg
# Processing: 792.jpg
# Processing: 793.jpg
# Processing: 794.jpg
# Processing: 795.jpg
# Processing: 796.jpg
# Processing: 797.jpg
# Processing: 798.jpg
# Processing: 799.jpg
# Processing: 8.jpg
# Processing: 80.jpg
# Processing: 800.jpg
# Processing: 801.jpg
# Processing: 802.jpg
# Processing: 803.jpg
# Processing: 804.jpg
# Processing: 805.jpg
# Processing: 806.jpg
# Processing: 807.jpg
# Processing: 808.jpg
# Processing: 809.jpg
# Processing: 81.jpg
# Processing: 810.jpg
# Processing: 811.jpg
# Processing: 812.jpg
# Processing: 813.jpg
# Processing: 814.jpg
# Processing: 815.jpg
# Processing: 816.jpg
# Processing: 817.jpg
# Processing: 818.jpg
# Processing: 819.jpg
# Processing: 82.jpg
# Processing: 820.jpg
# Processing: 821.jpg
# Processing: 822.jpg
# Processing: 823.jpg
# Processing: 824.jpg
# Processing: 825.jpg
# Processing: 826.jpg
# Processing: 827.jpg
# Processing: 828.jpg
# Processing: 829.jpg
# Processing: 83.jpg
# Processing: 830.jpg
# Processing: 831.jpg
# Processing: 832.jpg
# Processing: 833.jpg
# Processing: 834.jpg
# Processing: 835.jpg
# Processing: 836.jpg
# Processing: 837.jpg
# Processing: 838.jpg
# Processing: 839.jpg
# Processing: 84.jpg
# Processing: 840.jpg
# Processing: 841.jpg
# Processing: 842.jpg
# Processing: 843.jpg
# Processing: 844.jpg
# Processing: 845.jpg
# Processing: 846.jpg
# Processing: 847.jpg
# Processing: 848.jpg
# Processing: 849.jpg
# Processing: 85.jpg
# Processing: 850.jpg
# Processing: 851.jpg
# Processing: 852.jpg
# Processing: 853.jpg
# Processing: 854.jpg
# Processing: 855.jpg
# Processing: 856.jpg
# Processing: 857.jpg
# Processing: 858.jpg
# Processing: 859.jpg
# Processing: 86.jpg
# Processing: 860.jpg
# Processing: 861.jpg
# Processing: 862.jpg
# Processing: 863.jpg
# Processing: 864.jpg
# Processing: 865.jpg
# Processing: 866.jpg
# Processing: 867.jpg
# Processing: 868.jpg
# Processing: 869.jpg
# Processing: 87.jpg
# Processing: 870.jpg
# Processing: 871.jpg
# Processing: 872.jpg
# Processing: 873.jpg
# Processing: 874.jpg
# Processing: 875.jpg
# Processing: 876.jpg
# Processing: 877.jpg
# Processing: 878.jpg
# Processing: 879.jpg
# Processing: 88.jpg
# Processing: 880.jpg
# Processing: 881.jpg
# Processing: 882.jpg
# Processing: 883.jpg
# Processing: 884.jpg
# Processing: 885.jpg
# Processing: 886.jpg
# Processing: 887.jpg
# Processing: 888.jpg
# Processing: 889.jpg
# Processing: 89.jpg
# Processing: 890.jpg
# Processing: 891.jpg
# Processing: 892.jpg
# Processing: 893.jpg
# Processing: 894.jpg
# Processing: 895.jpg
# Processing: 896.jpg
# Processing: 897.jpg
# Processing: 898.jpg
# Processing: 899.jpg
# Processing: 9.jpg
# Processing: 90.jpg
# Processing: 900.jpg
# Processing: 901.jpg
# Processing: 902.jpg
# Processing: 903.jpg
# Processing: 904.jpg
# Processing: 905.jpg
# Processing: 906.jpg
# Processing: 907.jpg
# Processing: 908.jpg
# Processing: 909.jpg
# Processing: 91.jpg
# Processing: 910.jpg
# Processing: 911.jpg
# Processing: 912.jpg
# Processing: 913.jpg
# Processing: 914.jpg
# Processing: 915.jpg
# Processing: 916.jpg
# Processing: 917.jpg
# Processing: 918.jpg
# Processing: 919.jpg
# Processing: 92.jpg
# Processing: 920.jpg
# Processing: 921.jpg
# Processing: 922.jpg
# Processing: 923.jpg
# Processing: 924.jpg
# Processing: 925.jpg
# Processing: 926.jpg
# Processing: 927.jpg
# Processing: 928.jpg
# Processing: 929.jpg
# Processing: 93.jpg
# Processing: 930.jpg
# Processing: 931.jpg
# Processing: 932.jpg
# Processing: 933.jpg
# Processing: 934.jpg
# Processing: 935.jpg
# Processing: 936.jpg
# Processing: 937.jpg
# Processing: 938.jpg
# Processing: 939.jpg
# Processing: 94.jpg
# Processing: 940.jpg
# Processing: 941.jpg
# Processing: 942.jpg
# Processing: 943.jpg
# Processing: 944.jpg
# Processing: 945.jpg
# Processing: 946.jpg
# Processing: 947.jpg
# Processing: 948.jpg
# Processing: 949.jpg
# Processing: 95.jpg
# Processing: 950.jpg
# Processing: 951.jpg
# Processing: 952.jpg
# Processing: 953.jpg
# Processing: 954.jpg
# Processing: 955.jpg
# Processing: 956.jpg
# Processing: 957.jpg
# Processing: 958.jpg
# Processing: 959.jpg
# Processing: 96.jpg
# Processing: 960.jpg
# Processing: 961.jpg
# Processing: 962.jpg
# Processing: 963.jpg
# Processing: 964.jpg
# Processing: 965.jpg
# Processing: 966.jpg
# Processing: 967.jpg
# Processing: 968.jpg
# Processing: 969.jpg
# Processing: 97.jpg
# Processing: 970.jpg
# Processing: 971.jpg
# Processing: 972.jpg
# Processing: 973.jpg
# Processing: 974.jpg
# Processing: 975.jpg
# Processing: 976.jpg
# Processing: 977.jpg
# Processing: 978.jpg
# Processing: 979.jpg
# Processing: 98.jpg
# Processing: 980.jpg
# Processing: 981.jpg
# Processing: 982.jpg
# Processing: 983.jpg
# Processing: 984.jpg
# Processing: 985.jpg
# Processing: 986.jpg
# Processing: 987.jpg
# Processing: 988.jpg
# Processing: 989.jpg
# Processing: 99.jpg
# Processing: 990.jpg
# Processing: 991.jpg
# Processing: 992.jpg
# Processing: 993.jpg
# Processing: 994.jpg
# Processing: 995.jpg
# Processing: 996.jpg
# Processing: 997.jpg
# Processing: 998.jpg
# Processing: 999.jpg
# Model, PCA, and Label Encoder saved successfully!

# %%
# Function to preprocess and extract features for a single image
def preprocess_and_extract_features(image_path, image_size, apply_pca=False, pca=None):
    # Load the image
    image = cv2.imread(image_path)
    if image is None:
        raise ValueError(f"Could not load image at path: {image_path}")
    
    # Resize the image to the required size
    resized_image = cv2.resize(image, image_size)
    # Convert to grayscale for HOG feature extraction
    gray_image = cv2.cvtColor(resized_image, cv2.COLOR_BGR2GRAY)
    
    # Extract HOG features
    hog_features = extract_hog_features(gray_image)
    
    # If PCA was applied during training, apply it here as well
    if apply_pca and pca is not None:
        hog_features = pca.transform([hog_features])
    
    return hog_features

# Example usage for testing an image
image_path = '../dataset/images//bike-cropped.png'  # Path to your test image
IMAGE_SIZE = (128, 128)

# Load the PCA object (if PCA was used during training)
pca = joblib.load('pca_model.pkl')

# Load the trained SVM model
model = joblib.load('vehicle_detection_model.pkl')

# Load the label encoder
label_encoder = joblib.load('label_encoder.pkl')

# Preprocess the image and extract features
hog_features = preprocess_and_extract_features(image_path, IMAGE_SIZE, apply_pca=True, pca=pca)

# Now use your trained model to make a prediction
prediction = model.predict(hog_features)
predicted_class = label_encoder.inverse_transform(prediction)

print(f"Predicted class: {predicted_class}")
# Out:
# Predicted class: ['motorcycles']

# %%
import cv2
import os
import joblib
import numpy as np
from skimage.feature import hog

# Define the HOG feature extraction function
def extract_hog_features(image):
    features, _ = hog(image, orientations=9, pixels_per_cell=(8, 8),
                      cells_per_block=(2, 2), visualize=True)
    return features

# Function to extract and resize grid boxes from a frame
def extract_and_resize_grid(frame, grid_size, resized_grid_size=128):
    height, width, _ = frame.shape
    resized_grid_boxes = []
    positions = []
    for y in range(0, height, grid_size):
        for x in range(0, width, grid_size):
            grid_box = frame[y:y+grid_size, x:x+grid_size]
            if grid_box.shape[0] == grid_size and grid_box.shape[1] == grid_size:
                resized_box = cv2.resize(grid_box, (resized_grid_size, resized_grid_size))
                resized_grid_boxes.append(resized_box)
                positions.append((x, y))
    return resized_grid_boxes, positions

# Function to process video and save predictions
def process_video(input_path, output_path, model, label_encoder, pca=None, grid_size=500, resized_grid_size=128, output_dir="./Prediction/01_svc/resized_grid_boxes"):
    cap = cv2.VideoCapture(input_path)
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    print("Width:", width)
    print("Height:", height)
    print("Frame count:", frame_count)

    writer = cv2.VideoWriter(output_path, cv2.VideoWriter_fourcc(*'DIVX'), 20, (width, height))

    if not cap.isOpened():
        print("Error opening the video file.")
        return

    # Create the output directory if it does not exist
    os.makedirs(output_dir, exist_ok=True)
    frame_idx = 0

    while cap.isOpened():
        ret, frame = cap.read()
        if ret:
            current_grid_size = grid_size
            resized_grid_boxes, positions = extract_and_resize_grid(frame, current_grid_size, resized_grid_size)
            print(f"Processing Frame: {frame_idx}")

            for i, (box, (x, y)) in enumerate(zip(resized_grid_boxes, positions)):
                grid_folder = os.path.join(output_dir, f"frame_{frame_idx}")
                os.makedirs(grid_folder, exist_ok=True)
                gray_image = cv2.cvtColor(box, cv2.COLOR_BGR2GRAY)
                hog_features = extract_hog_features(gray_image)
                if pca is not None:
                    hog_features = pca.transform([hog_features])
                else:
                    hog_features = np.array(hog_features).reshape(1, -1)
                prediction = model.predict(hog_features)
                predicted_class = label_encoder.inverse_transform(prediction)[0]
                print(f"Prediction for Grid {i}: {predicted_class}")
                if predicted_class == 'cars' or predicted_class == 'motorcycles':
                    box_filename = os.path.join(grid_folder, f"grid_{i}_{predicted_class}.png")
                    cv2.imwrite(box_filename, box)

                    cv2.rectangle(frame, (x, y), (x + current_grid_size, y + current_grid_size), (0, 255, 0), 2)
                    cv2.putText(frame, predicted_class, (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)

            writer.write(frame)
            frame_idx += 1
        else:
            break

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    cap.release()
    writer.release()
    cv2.destroyAllWindows()
    print(f"Video processing complete. Output saved to {output_path}")
    print(f"Resized grid boxes saved in {output_dir}")

input_video_path = '../dataset/sample videos/sample.mp4'  
output_video_path = './Prediction/01_svc/grid_video.mp4' 

model = joblib.load('vehicle_detection_model.pkl')
pca = joblib.load('pca_model.pkl') if os.path.exists('pca_model.pkl') else None

label_encoder = joblib.load('label_encoder.pkl')

process_video(input_video_path, output_video_path, model, label_encoder, pca, grid_size=350)

# %%
import os
import cv2
import numpy as np

# Function to load images from a directory and return them as a list
def load_images_from_folder(folder_path):
    images = []
    labels = []
    for label_folder in os.listdir(folder_path):
        label_folder_path = os.path.join(folder_path, label_folder)
        for filename in os.listdir(label_folder_path):
            img_path = os.path.join(label_folder_path, filename)
            img = cv2.imread(img_path)
            if img is not None:
                images.append(img)
                labels.append(label_folder)  
    return images, labels

# Load dataset
dataset_folder = '../dataset/images'
images, labels = load_images_from_folder(dataset_folder)
print(f"Loaded {len(images)} images with corresponding labels.")
# Out:
# Loaded 8110 images with corresponding labels.

# %%
import cv2
import numpy as np
from skimage.feature import hog

# Extract color histogram features
def extract_color_histogram(image, bins=32):
    hsv_image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
    hist_features = []
    for i in range(3): 
        hist = np.histogram(hsv_image[:, :, i], bins=bins, range=(0, 256))[0]
        hist_features.append(hist)
    return np.concatenate(hist_features)

# Extract spatial binning features
def extract_spatial_binning(image, size=(32, 32)):
    return cv2.resize(image, size).ravel()

# Extract HOG features
def extract_hog_features(image, orientations=9, pixels_per_cell=(8, 8), cells_per_block=(2, 2)):
    gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    
    if gray_image.shape[0] >= pixels_per_cell[0] * cells_per_block[0] and gray_image.shape[1] >= pixels_per_cell[1] * cells_per_block[1]:
        features, _ = hog(gray_image, orientations=orientations, pixels_per_cell=pixels_per_cell,
                          cells_per_block=cells_per_block, visualize=True)
        return features
    else:
        # Return zeros if the image is too small for HOG extraction
        print(f"Image is too small for HOG feature extraction. Size: {gray_image.shape}")
        return np.zeros(orientations * ((gray_image.shape[0] // pixels_per_cell[0]) // cells_per_block[0]) *
                        ((gray_image.shape[1] // pixels_per_cell[1]) // cells_per_block[1]))

# Extract combined features
def extract_combined_features(image):
    # color_features = extract_color_histogram(image, bins=32)
    spatial_features = extract_spatial_binning(image, size=(32, 32))
    hog_features = extract_hog_features(image) 
    
    # Concatenate all features (ensure all arrays are the same size)
    combined_features = np.concatenate(( spatial_features, hog_features))
    return combined_features

# Assuming `images` is a list of images loaded using cv2
features = [extract_combined_features(img) for img in images]

# Convert the list of features into a numpy array
features_arr = np.array(features)

print(f"Features array shape: {features_arr.shape}")
# Out:
# Image is too small for HOG feature extraction. Size: (14, 18)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 43
#      40     return combined_features
#      42 # Assuming `images` is a list of images loaded using cv2
# ---> 43 features = [extract_combined_features(img) for img in images]
#      45 # Convert the list of features into a numpy array
#      46 features_arr = np.array(features)
#
# Cell In[4], line 36, in extract_combined_features(image)
#      33 def extract_combined_features(image):
#      34     # color_features = extract_color_histogram(image, bins=32)
#      35     spatial_features = extract_spatial_binning(image, size=(32, 32))
# ---> 36     hog_features = extract_hog_features(image)
#      38     # Concatenate all features (ensure all arrays are the same size)
#      39     combined_features = np.concatenate(( spatial_features, hog_features))
#
# Cell In[4], line 23, in extract_hog_features(image, orientations, pixels_per_cell, cells_per_block)
#      20 gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
#      22 if gray_image.shape[0] >= pixels_per_cell[0] * cells_per_block[0] and gray_image.shape[1] >= pixels_per_cell[1] * cells_per_block[1]:
# ---> 23     features, _ = hog(gray_image, orientations=orientations, pixels_per_cell=pixels_per_cell,
#      24                       cells_per_block=cells_per_block, visualize=True)
#      25     return features
#      26 else:
#      27     # Return zeros if the image is too small for HOG extraction
#
# File d:\VS-code\Github\Project02\vnev\Lib\site-packages\skimage\_shared\utils.py:438, in channel_as_last_axis.__call__.<locals>.fixed_func(*args, **kwargs)
#     435 channel_axis = kwargs.get('channel_axis', None)
#     437 if channel_axis is None:
# --> 438     return func(*args, **kwargs)
#     440 # TODO: convert scalars to a tuple in anticipation of eventually
#     441 #       supporting a tuple of channel axes. Right now, only an
#     442 #       integer or a single-element tuple is supported, though.
#     443 if np.isscalar(channel_axis):
#
# File d:\VS-code\Github\Project02\vnev\Lib\site-packages\skimage\feature\_hog.py:292, in hog(image, orientations, pixels_per_cell, cells_per_block, block_norm, visualize, transform_sqrt, feature_vector, channel_axis)
#     285                 centre = tuple([r * c_row + c_row // 2, c * c_col + c_col // 2])
#     286                 rr, cc = draw.line(
#     287                     int(centre[0] - dc),
#     288                     int(centre[1] + dr),
#     289                     int(centre[0] + dc),
#     290                     int(centre[1] - dr),
#     291                 )
# --> 292                 hog_image[rr, cc] += orientation_histogram[r, c, o]
#     294 """
#     295 The fourth stage computes normalization, which takes local groups of
#     296 cells and contrast normalizes their overall responses before passing
#    (...)
#     306 Gradient (HOG) descriptors.
#     307 """
#     309 n_blocks_row = (n_cells_row - b_row) + 1
#
# KeyboardInterrupt:

# %%
from sklearn.preprocessing import LabelEncoder

# Encode labels into numerical values (not one-hot encoded)
label_encoder = LabelEncoder()
encoded_labels = label_encoder.fit_transform(labels)  # No need to use one-hot encoding for SVM

# %%
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, encoded_labels, test_size=0.2, random_state=42)

# Train a Support Vector Machine (SVM) classifier
svm_model = SVC(kernel='linear')
svm_model.fit(X_train, y_train)

# Test the model and print the classification report
y_pred = svm_model.predict(X_test)
print(classification_report(y_test, y_pred, target_names=label_encoder.classes_))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 10
#       8 # Train a Support Vector Machine (SVM) classifier
#       9 svm_model = SVC(kernel='linear')
# ---> 10 svm_model.fit(X_train, y_train)
#      12 # Test the model and print the classification report
#      13 y_pred = svm_model.predict(X_test)
#
# File d:\VS-code\Github\Project02\vnev\Lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File d:\VS-code\Github\Project02\vnev\Lib\site-packages\sklearn\svm\_base.py:190, in BaseLibSVM.fit(self, X, y, sample_weight)
#     188     check_consistent_length(X, y)
#     189 else:
# --> 190     X, y = self._validate_data(
#     191         X,
#     192         y,
#     193         dtype=np.float64,
#     194         order="C",
#     195         accept_sparse="csr",
#     196         accept_large_sparse=False,
#     197     )
#     199 y = self._validate_targets(y)
#     201 sample_weight = np.asarray(
#     202     [] if sample_weight is None else sample_weight, dtype=np.float64
#     203 )
#
# File d:\VS-code\Github\Project02\vnev\Lib\site-packages\sklearn\base.py:650, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     648         y = check_array(y, input_name="y", **check_y_params)
#     649     else:
# --> 650         X, y = check_X_y(X, y, **check_params)
#     651     out = X, y
#     653 if not no_val_X and check_params.get("ensure_2d", True):
#
# File d:\VS-code\Github\Project02\vnev\Lib\site-packages\sklearn\utils\validation.py:1301, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1296         estimator_name = _check_estimator_name(estimator)
#    1297     raise ValueError(
#    1298         f"{estimator_name} requires y to be passed, but the target y is None"
#    1299     )
# -> 1301 X = check_array(
#    1302     X,
#    1303     accept_sparse=accept_sparse,
#    1304     accept_large_sparse=accept_large_sparse,
#    1305     dtype=dtype,
#    1306     order=order,
#    1307     copy=copy,
#    1308     force_writeable=force_writeable,
#    1309     force_all_finite=force_all_finite,
#    1310     ensure_2d=ensure_2d,
#    1311     allow_nd=allow_nd,
#    1312     ensure_min_samples=ensure_min_samples,
#    1313     ensure_min_features=ensure_min_features,
#    1314     estimator=estimator,
#    1315     input_name="X",
#    1316 )
#    1318 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1320 check_consistent_length(X, y)
#
# File d:\VS-code\Github\Project02\vnev\Lib\site-packages\sklearn\utils\validation.py:1012, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1010         array = xp.astype(array, dtype, copy=False)
#    1011     else:
# -> 1012         array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#    1013 except ComplexWarning as complex_warning:
#    1014     raise ValueError(
#    1015         "Complex data not supported\n{}\n".format(array)
#    1016     ) from complex_warning
#
# File d:\VS-code\Github\Project02\vnev\Lib\site-packages\sklearn\utils\_array_api.py:751, in _asarray_with_order(array, dtype, order, copy, xp, device)
#     749     array = numpy.array(array, order=order, dtype=dtype)
#     750 else:
# --> 751     array = numpy.asarray(array, order=order, dtype=dtype)
#     753 # At this point array is a NumPy ndarray. We convert it to an array
#     754 # container that is consistent with the input's namespace.
#     755 return xp.asarray(array)
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (6488,) + inhomogeneous part.

# %%
# Sliding window function for object localization
def sliding_window(image, step_size, window_size):
    for y in range(0, image.shape[0] - window_size[1], step_size):
        for x in range(0, image.shape[1] - window_size[0], step_size):
            yield (x, y, image[y:y + window_size[1], x:x + window_size[0]])

# Function to detect vehicles in a video frame using sliding window and classifier
def detect_vehicles_in_frame(frame, model, label_encoder, window_size=(128, 128), step_size=32):
    detected_objects = []
    for (x, y, window) in sliding_window(frame, step_size, window_size):
        if window.shape[0] != window_size[1] or window.shape[1] != window_size[0]:
            continue
        
        # Extract features for the current window
        window_features = extract_combined_features(window).reshape(1, -1)
        
        # Predict the class using the trained model
        prediction = model.predict(window_features)
        predicted_class = label_encoder.inverse_transform(prediction)[0]
        
        if predicted_class != 'no_vehicle':
            detected_objects.append((x, y, predicted_class))
            cv2.rectangle(frame, (x, y), (x + window_size[0], y + window_size[1]), (0, 255, 0), 2)
            cv2.putText(frame, predicted_class, (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)
    
    return frame, detected_objects

# %%
def process_video(input_path, output_path, model, label_encoder, window_size=(128, 128), step_size=32):
    cap = cv2.VideoCapture(input_path)
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    writer = cv2.VideoWriter(output_path, cv2.VideoWriter_fourcc(*'DIVX'), 20, (width, height))

    frame_idx = 0
    while cap.isOpened():
        ret, frame = cap.read()
        if ret:
            # Detect vehicles in the current frame
            frame, detected_objects = detect_vehicles_in_frame(frame, model, label_encoder, window_size, step_size)
            writer.write(frame)
            frame_idx += 1
        else:
            break

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    cap.release()
    writer.release()
    cv2.destroyAllWindows()
    print(f"Video processing complete. Output saved to {output_path}")

# Example usage
input_video_path = './dataset/sample_videos/sample_2.mp4'
output_video_path = './Prediction/vehicle_detection_output.mp4'

# Process the video
process_video(input_video_path, output_video_path, svm_model, label_encoder)
